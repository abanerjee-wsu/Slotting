# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np

from sklearn.cluster import KMeans
from sklearn.cluster import AgglomerativeClustering

from scipy.spatial.distance import cdist
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import normalize
from sklearn import preprocessing
from sklearn.utils import resample

import statsmodels.stats.api as sms
import statsmodels.api as sm
from statsmodels.graphics.gofplots import qqplot
import scipy.stats as stats
from scipy.stats import pearsonr
import scipy.cluster.hierarchy as shc

import pylab 

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()  # for plot styling

pd.set_option('display.float_format',lambda x: '%.3f' %x)

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Load the dataset

# %%
# Load the datasets

this_year = 2018

# Load the datasets for 2018 data
dataYear = pd.read_csv(r'C:\Users\abandyopadhyay\ALOKPARNA\RCV_SLOTTING\Dataset\Slotting_2018.csv', header=0, encoding = 'unicode_escape')
print("----- Feature Set for Current Year ----- \n", list(dataYear.columns))

# # Load the datasets for 2017 data
# dataPriorYear = pd.read_csv(r'C:\Users\abandyopadhyay\ALOKPARNA\RCV_SLOTTING\Dataset\Slotting_2017.csv', header=0, encoding = 'unicode_escape')
# print("\n----- Feature Set for Prior Year ----- \n", list(dataPriorYear.columns))

# Load the datasets for 2019 data
dataFutureYear = pd.read_csv(r'C:\Users\abandyopadhyay\ALOKPARNA\RCV_SLOTTING\Dataset\Slotting_2019.csv', header=0, encoding = 'unicode_escape')
print("\n----- Feature Set for Future Year ----- \n", list(dataFutureYear.columns))

dataYear = dataYear.fillna(0)
# dataPriorYear = dataPriorYear.fillna(0)
dataFutureYear = dataFutureYear.fillna(0)
# Out:
# ----- Feature Set for Current Year -----
#  ['UniqueId', 'Department', 'Category', 'SubCategory', 'Material', 'Style', 'Dimension', 'ProductSize', 'Volume', 'InventorySegment', 'Color', 'UPC', 'Season_SKU_Introduced', 'Year_SKU_Introduced', 'History_Size_Pct', 'Month', 'Season', 'Year', 'Quarter', 'PlannedUnits', 'PDXPlannedUnits', 'Orders', 'Ordered_Units', 'Avg_Daily_Ordered_Units', 'Days_Ordered', 'Order_Volume', 'Avg_Daily_Volume', 'Experiment_Id']
#
# ----- Feature Set for Future Year -----
#  ['UniqueId', 'Department', 'Category', 'SubCategory', 'Material', 'Style', 'Dimension', 'ProductSize', 'Volume', 'InventorySegment', 'Color', 'UPC', 'Season_SKU_Introduced', 'Year_SKU_Introduced', 'History_Size_Pct', 'Month', 'Season', 'Year', 'Quarter', 'PlannedUnits', 'PDXPlannedUnits', 'Orders', 'Ordered_Units', 'Avg_Daily_Ordered_Units', 'Days_Ordered', 'Order_Volume', 'Avg_Daily_Volume', 'Experiment_Id']

# %% [markdown]
# ### Function Definitions

# %%
# Function to identify whether a product is new or not and add that as a feature in the dataset
def add_NewProduct(data):
    data.loc[(data.Year_SKU_Introduced < this_year) | ((data['Year_SKU_Introduced']).isnull()), 'NewProduct'] = '0' # Existing product
    data.loc[data.Year_SKU_Introduced >= this_year, 'NewProduct'] = '1' # New product
    return (data)

# %%
# Function to add future year's Contract' as a feature in the current year dataset
def add_FutureContract(data, dataFuture):
    dataFuture.loc[dataFuture.PlannedUnits != 0, 'Contract'] = dataFuture['PlannedUnits']
    dataFuture.loc[dataFuture.PlannedUnits == 0, 'Contract'] = dataFuture['PDXPlannedUnits']    
    data['Future_Contract'] = dataFuture['Contract']
    return (data)

# %%
# Function to add 'Contract' as a feature in the dataset
def add_Contract(data):
    data.loc[data.PlannedUnits != 0, 'Contract'] = data['PlannedUnits']
    data.loc[data.PlannedUnits == 0, 'Contract'] = data['PDXPlannedUnits']
    return (data)

# %%
# Function to add 'Popularity': a measure of how much was contracted and how much was actually sold
def add_Popularity(data):
    data['Popularity'] = ((data['Ordered_Units']-data['Contract'])/data['Ordered_Units'])*100
    return (data)

# %%
# Function to Group products by Experiment Id
def group_by_expId(data):
    groupedData = data.groupby(['Experiment_Id']).agg({'Contract': 'sum', 'Orders': 'sum', 'Ordered_Units': 'sum', 'Days_Ordered': 'sum', 'Order_Volume': 'sum', 'Avg_Daily_Volume': 'mean'})
    # Remove the index and flatten the dataset
    groupedData.reset_index(inplace=True)
    print("Grouped dataset (by Experiment Id) shape: ", groupedData.shape)
    return (groupedData)

# %%
# Function to Group products by Experiment Id and Seasons
def group_by_Seasons(data):
    groupedData = data.groupby(['Experiment_Id', 'Season']).agg({'Contract': 'sum', 'Orders': 'sum', 'Ordered_Units': 'sum', 'Days_Ordered': 'sum', 'Order_Volume': 'sum', 'Avg_Daily_Volume': 'mean'})
    # Remove the index and flatten the dataset
    groupedData.reset_index(inplace=True)
    print("Grouped dataset (by Experiment Id and Seasons) shape: ", groupedData.shape)
    return (groupedData)

# %%
# Function to Group products by Experiment Id and Categorical Descriptions
def group_by_Categoricals(data):
    groupedData = data.groupby(['Experiment_Id', 'Department', 'Category', 'SubCategory', 'Material', 'Style', 'Dimension', 'ProductSize', 'Volume', 'InventorySegment', 'Color', 'UPC', 'NewProduct']).agg({'Demand': 'sum', 'Orders': 'sum','Ordered_Units': 'sum', 'Avg_Daily_Ordered_Units': 'mean', 'Days_Ordered': 'sum', 'Order_Volume': 'sum', 'Avg_Daily_Volume': 'mean'})
    # Remove index and flatten the dataset
    groupedData.reset_index(inplace=True)
    print("Grouped dataset (Experiment Id and Categoricals) shape: ", groupedData.shape)
    return (groupedData)

# %%
# Function to Group products by Experiment Id, Seasons and Categorical Descriptions
def group_by_SeasonsAndCategoricals(data):
    groupedData = data.groupby(['Experiment_Id', 'Season', 'Department', 'Category', 'SubCategory', 'Material', 'Style', 'Dimension', 'ProductSize', 'Volume', 'InventorySegment', 'Color', 'UPC', 'NewProduct']).agg({'Contract': 'sum', 'Future_Contract': 'sum', 'Popularity': 'sum', 'Orders': 'sum','Ordered_Units': 'sum', 'Avg_Daily_Ordered_Units': 'mean', 'Days_Ordered': 'sum', 'Order_Volume': 'sum', 'Avg_Daily_Volume': 'mean'})
    # Remove index and flatten the dataset
    groupedData.reset_index(inplace=True)
    print("\nGrouped dataset (Experiment Id, Seasons and Categoricals) shape: ", groupedData.shape)
    return (groupedData)

# %%
# Function to select the Top80 selling products
def get_Top80(data):
    # Calculate % Ordered_Units 
    totalOrdUnits = data['Ordered_Units'].sum()
    data['Pct_OrdUnits'] = (data['Ordered_Units']/totalOrdUnits)*100

    # Sort the dataset based on % Ordered_Units 
    data = data.sort_values('Pct_OrdUnits',ascending=False)
    data['Cumsum_Pct_OrdUnits'] = data['Pct_OrdUnits'].cumsum()

    # Find the orders with Top 80 sales (ordered units)
    dataTop80 = data[data.Cumsum_Pct_OrdUnits <= 80]

    # Drop the Pct_OrdUnits and Cumsum_Pct_OrdUnits columns
    dataTop80 = dataTop80.drop(['Pct_OrdUnits', 'Cumsum_Pct_OrdUnits'], axis=1)

    print("Dataset shape after retaining the Top80 selling products: ", dataTop80.shape)
    return (dataTop80)

# %%
# Function for K-Means clustering
def KMeans_clusterLabels(data, n):# Cluster data using k-means and get the cluster labels
    model = KMeans(n_clusters=n, random_state=1)
    model.fit(data)
    model_p = model.predict(data)
    # Get cluster labels
    cluster_label = model.labels_
    #Plot the clusters
    plt.scatter(data.iloc[:, 0], data.iloc[:, 1], c=cluster_label, s=50, cmap='viridis')
    centers = model.cluster_centers_
    plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5)
    
    # Recoding the Cluster '0' as Cluster 'n'
    for i in range(len(cluster_label)): 
        if cluster_label[i] == 0:
            cluster_label[i] = n
    
    return (cluster_label)

# %%
# Function for Agglomerative clustering
def Agglomerative_clusterLabels(data_scaled, n):# Cluster data using k-means and get the cluster labels
    model = AgglomerativeClustering(n_clusters=n, affinity='euclidean', linkage='ward')
    model.fit_predict(data_scaled)
    # Get cluster labels
    cluster_label = model.labels_
    #Plot the clusters
    plt.scatter(data.iloc[:, 0], data.iloc[:, 1], c=cluster_label, s=50, cmap='viridis')

    # Recoding the Cluster '0' as Cluster 'n'
    for i in range(len(cluster_label)): 
        if cluster_label[i] == 0:
            cluster_label[i] = n
    
    return (cluster_label)

# %%
# Function for adding binary values for ClusterLabels
def add_binary_response_Kmeans_clusterLabels(data):
    data.loc[data.KMeans_Cluster3_Label == 1, 'Cluster_1'] = '1'
    data.loc[data.KMeans_Cluster3_Label != 1, 'Cluster_1'] = '0'
    
    data.loc[data.KMeans_Cluster3_Label == 2, 'Cluster_2'] = '1'
    data.loc[data.KMeans_Cluster3_Label != 2, 'Cluster_2'] = '0'
    
    data.loc[data.KMeans_Cluster3_Label == 3, 'Cluster_3'] = '1'
    data.loc[data.KMeans_Cluster3_Label != 3, 'Cluster_3'] = '0'
    
    return (data)

# %%
# Function for creating Classification Dataset
def create_Classification_Dataset(data):
    # Add the new feature 'Suggested_Storage_Type' and the target 'Class' based on the 'Avg_Daily_Volume'
    data.loc[data.Avg_Daily_Volume <= 4216.22, 'Suggested_Storage_Type'] = 'Flat Rack'
    data.loc[data.Avg_Daily_Volume <= 4216.22, 'Class'] = '1'
    data.loc[(data.Avg_Daily_Volume > 4216.22) & (data.Avg_Daily_Volume <= 21081.6), 'Suggested_Storage_Type'] = 'Flow Rack' 
    data.loc[(data.Avg_Daily_Volume > 4216.22) & (data.Avg_Daily_Volume <= 21081.6), 'Class'] = '2' 
    data.loc[data.Avg_Daily_Volume > 21081.6, 'Suggested_Storage_Type'] = 'Big Pack'
    data.loc[data.Avg_Daily_Volume > 21081.6, 'Class'] = '3'

    return (data)

# %%
# Function to calculate Pearson Co-edfficient and p-values of a matrix
def corrcoef_loop(matrix):
    rows, cols = matrix.shape[0], matrix.shape[1]
    r = np.ones(shape=(rows, rows))
    p = np.ones(shape=(rows, rows))
    for i in range(rows):
        for j in range(i+1, rows):
            r_, p_ = pearsonr(matrix[i], matrix[j])
            r[i, j] = r[j, i] = r_
            p[i, j] = p[j, i] = p_
    return r, p

# %%
# Function for Histogram plot
def plot_Histograms(data):
    fig, ax = plt.subplots(1, 2, figsize=(20,4))
    volume = data['Volume'].values
    sns.distplot(volume, ax=ax[0], color='r')
    ax[0].set_title('Distribution of Volume', fontsize=14)
    ax[0].set_xlim([min(volume), max(volume)])

    orders = data['Orders'].values
    sns.distplot(orders, ax=ax[1], color='b')
    ax[1].set_title('Distribution of Orders', fontsize=14)
    ax[1].set_xlim([min(orders), max(orders)])
    
    fig, ax = plt.subplots(1, 2, figsize=(20,4))
    ordered_Units = data['Ordered_Units'].values
    sns.distplot(ordered_Units, ax=ax[0], color='g')
    ax[0].set_title('Distribution of Ordered_Units', fontsize=14)
    ax[0].set_xlim([min(ordered_Units), max(ordered_Units)])
    
    avg_Daily_Ordered_Units = data['Avg_Daily_Ordered_Units'].values
    sns.distplot(avg_Daily_Ordered_Units, ax=ax[1], color='m')
    ax[1].set_title('Distribution of Avg_Daily_Ordered_Units', fontsize=14)
    ax[1].set_xlim([min(avg_Daily_Ordered_Units), max(avg_Daily_Ordered_Units)])
    
    fig, ax = plt.subplots(1, 2, figsize=(20,4))
    days_Ordered = data['Days_Ordered'].values
    sns.distplot(days_Ordered, ax=ax[0], color='r')
    ax[0].set_title('Distribution of Days_Ordered', fontsize=14)
    ax[0].set_xlim([min(days_Ordered), max(days_Ordered)])
    
    order_Volume = data['Order_Volume'].values
    sns.distplot(order_Volume, ax=ax[1], color='b')
    ax[1].set_title('Distribution of Order_Volume', fontsize=14)
    ax[1].set_xlim([min(order_Volume), max(order_Volume)])    
    
    fig, ax = plt.subplots(1, 2, figsize=(20,4))
    avg_Daily_Volume = data['Avg_Daily_Volume'].values
    sns.distplot(avg_Daily_Volume, ax=ax[0], color='g')
    ax[0].set_title('Distribution of Avg_Daily_Volume', fontsize=14)
    ax[0].set_xlim([min(avg_Daily_Volume), max(avg_Daily_Volume)])

# %%
# Function for KSTest and QQplot
def ksTest_QQPlots(data):
    print("Volume: ", stats.kstest(data['Volume'], 'norm'))
    qqplot(data['Volume'], line='s')
    plt.show()
    print("Orders: ", stats.kstest(data['Orders'], 'norm'))
    qqplot(data['Orders'], line='s')
    plt.show()
    print("Ordered_Units: ", stats.kstest(data['Ordered_Units'], 'norm'))
    qqplot(data['Ordered_Units'], line='s')
    plt.show()
    print("Avg_Daily_Ordered_Units: ", stats.kstest(data['Avg_Daily_Ordered_Units'], 'norm'))
    qqplot(data['Avg_Daily_Ordered_Units'], line='s')
    plt.show()
    print("Days_Ordered: ", stats.kstest(data['Days_Ordered'], 'norm'))
    qqplot(data['Days_Ordered'], line='s')
    plt.show()
    print("Order_Volume: ", stats.kstest(data['Order_Volume'], 'norm'))
    qqplot(data['Order_Volume'], line='s')
    plt.show()
    print("Avg_Daily_Volume: ", stats.kstest(data['Avg_Daily_Volume'], 'norm'))
    qqplot(data['Avg_Daily_Volume'], line='s')
    plt.show()

# %% [markdown]
# ### Dataset ETL and Selection of Top80 Sales

# %%
# Add a new feature 'currentContract'
dataYear = add_Contract(dataYear)

# Add a new feature 'futureContract'
dataYear = add_FutureContract(dataYear, dataFutureYear)

# Remove those Data for which there are no Orders
dfOrders = dataYear[dataYear.Orders != 0]

# Add a new feature 'NewProduct' to identify whether a product is New or Existing
dfOrders = add_NewProduct(dfOrders)
print("0: Existing Product; 1: New Product")
print(dfOrders['NewProduct'].value_counts())

# Add a new feature 'popularity' to measure how much was contracted and how much was actually sold
dfOrders = add_Popularity(dfOrders)

# Group yearly dataset by Experiment_Id, Seasons and Categoricals
groupedSeasons = group_by_SeasonsAndCategoricals(dfOrders)

groupedSpring = groupedSeasons.loc[groupedSeasons['Season'] == 0].drop(['Season'], axis=1)
groupedFall = groupedSeasons.loc[groupedSeasons['Season'] == 1].drop(['Season'], axis=1)
print("Spring with categorical dataset shape: ", groupedSpring.shape)
print("Fall with categorical dataset shape: ", groupedFall.shape)

dfSpring_Top80 = get_Top80(groupedSpring)
dfFall_Top80 = get_Top80(groupedFall)

print("\n----- Feature Set : dfSpring_Top80 ----- \n", list(dfSpring_Top80.columns))
print("\n----- Feature Set : dfFall_Top80 ----- \n", list(dfFall_Top80.columns))
# Out:
# 0: Existing Product; 1: New Product
# 0    131966
# 1     25081
# Name: NewProduct, dtype: int64
#
# Grouped dataset (Experiment Id, Seasons and Categoricals) shape:  (33005, 23)
# Spring with categorical dataset shape:  (15050, 22)
# Fall with categorical dataset shape:  (17955, 22)
# Dataset shape after retaining the Top80 selling products:  (2280, 22)
# Dataset shape after retaining the Top80 selling products:  (2548, 22)
#
# ----- Feature Set : dfSpring_Top80 -----
#  ['Experiment_Id', 'Department', 'Category', 'SubCategory', 'Material', 'Style', 'Dimension', 'ProductSize', 'Volume', 'InventorySegment', 'Color', 'UPC', 'NewProduct', 'Contract', 'Future_Contract', 'Popularity', 'Orders', 'Ordered_Units', 'Avg_Daily_Ordered_Units', 'Days_Ordered', 'Order_Volume', 'Avg_Daily_Volume']
#
# ----- Feature Set : dfFall_Top80 -----
#  ['Experiment_Id', 'Department', 'Category', 'SubCategory', 'Material', 'Style', 'Dimension', 'ProductSize', 'Volume', 'InventorySegment', 'Color', 'UPC', 'NewProduct', 'Contract', 'Future_Contract', 'Popularity', 'Orders', 'Ordered_Units', 'Avg_Daily_Ordered_Units', 'Days_Ordered', 'Order_Volume', 'Avg_Daily_Volume']

# %%
dfSpring_Top80
# Out:
#        Experiment_Id           Department             Category  \
# 3258            6236                Men's          Accessories
# 2726            5581                Men's          Accessories
# 15864          23691                Men's     First Layer Tops
# 3266            6240                Men's          Accessories
# 15866          23692                Men's     First Layer Tops
# 15870          23694                Men's     First Layer Tops
# 16031          23886                Men's     First Layer Tops
# 16037          23889                Men's     First Layer Tops
# 15987          23834                Men's     First Layer Tops
# 2724            5580                Men's          Accessories
# 3244            6226                Men's          Accessories
# 15993          23837                Men's     First Layer Tops
# 2717            5571                Men's          Accessories
# 2730            5583                Men's          Accessories
# 3264            6239                Men's          Accessories
# 15868          23693                Men's     First Layer Tops
# 15872          23695                Men's     First Layer Tops
# 2743            5598                Men's          Accessories
# 15949          23746                Men's     First Layer Tops
# 15943          23743                Men's     First Layer Tops
# 16033          23887                Men's     First Layer Tops
# 16039          23890                Men's     First Layer Tops
# 16059          23941                Men's     First Layer Tops
# 3274            6247                Men's          Accessories
# 15989          23835                Men's     First Layer Tops
# 16053          23938                Men's     First Layer Tops
# 13506          19200                Men's     First Layer Tops
# 13512          19203                Men's     First Layer Tops
# 3272            6245                Men's          Accessories
# 15892          23707                Men's     First Layer Tops
# ...              ...                  ...                  ...
# 27716          38549  Personal Protective     First Layer Tops
# 14027          19604                Men's     First Layer Tops
# 16483          24434                Men's     First Layer Tops
# 32295          46065              Women's            Outerwear
# 8084           11798                Men's  First Layer Bottoms
# 9668           15523                Men's  First Layer Bottoms
# 16245          24306                Men's     First Layer Tops
# 24283          33755                Men's            Outerwear
# 4356            8087                Men's  First Layer Bottoms
# 13343          19095                Men's     First Layer Tops
# 17091          25405                Men's     First Layer Tops
# 11500          16461                Men's  First Layer Bottoms
# 21521          31179                Men's            Outerwear
# 24255          33741                Men's            Outerwear
# 10174          15776                Men's  First Layer Bottoms
# 16767          24697                Men's     First Layer Tops
# 31287          43035              Women's  First Layer Bottoms
# 15343          23183                Men's     First Layer Tops
# 4203            7166                Men's  First Layer Bottoms
# 14228          19971                Men's     First Layer Tops
# 22862          31966                Men's            Outerwear
# 5382            8924                Men's  First Layer Bottoms
# 24876          34367                Men's            Outerwear
# 10960          16177                Men's  First Layer Bottoms
# 25150          35283  Personal Protective  First Layer Bottoms
# 5208            8834                Men's  First Layer Bottoms
# 9746           15562                Men's  First Layer Bottoms
# 7509           11343                Men's  First Layer Bottoms
# 11243          16326                Men's  First Layer Bottoms
# 24071          33645                Men's            Outerwear
#
#                 SubCategory    Material  \
# 3258               Headwear     A18-BLK
# 2726               Headwear  100289-211
# 15864                 Knits     K87-BLK
# 3266               Headwear     A18-CLH
# 15866                 Knits     K87-BLK
# 15870                 Knits     K87-BLK
# 16031                 Knits     K87-NVY
# 16037                 Knits     K87-NVY
# 15987                 Knits     K87-HGY
# 2724               Headwear  100289-001
# 3244               Headwear     A18-019
# 15993                 Knits     K87-HGY
# 2717               Headwear  100286-039
# 2730               Headwear  100289-301
# 3264               Headwear     A18-BRN
# 15868                 Knits     K87-BLK
# 15872                 Knits     K87-BLK
# 2743               Headwear  101195-001
# 15949                 Knits     K87-DES
# 15943                 Knits     K87-DES
# 16033                 Knits     K87-NVY
# 16039                 Knits     K87-NVY
# 16059                 Knits     K87-PRT
# 3274               Headwear     A18-NVY
# 15989                 Knits     K87-HGY
# 16053                 Knits     K87-PRT
# 13506                 Knits  100410-026
# 13512                 Knits  100410-026
# 3272               Headwear     A18-HGY
# 15892                 Knits     K87-BLS
# ...                     ...         ...
# 27716                Wovens  100432-201
# 14027                 Knits  101125-412
# 16483                Sweats  100617-034
# 32295  Bottoms/Bib Overalls  102438-211
# 8084      Non-Denim Bottoms  102517-909
# 9668      Non-Denim Bottoms     B01-BLK
# 16245                Sweats  100074-026
# 24283     Jackets/Pullovers    J141-DKB
# 4356          Denim Bottoms  102804-964
# 13343                 Knits  100374-034
# 17091                Sweats    K121-BLK
# 11500     Non-Denim Bottoms    B159-NVY
# 21521  Bottoms/Bib Overalls     R06-DKB
# 24255     Jackets/Pullovers    J141-BLK
# 10174     Non-Denim Bottoms     B11-MOS
# 16767                Sweats  103191-001
# 31287                Shorts  102094-257
# 15343                 Knits    K231-CRH
# 4203          Denim Bottoms  101496-420
# 14228                 Knits  102960-083
# 22862          Coats/Parkas     C55-BLK
# 5382          Denim Bottoms     B17-DST
# 24876                 Vests     V33-GVL
# 10960     Non-Denim Bottoms    B151-NVY
# 25150         Denim Bottoms  FRB004-MDS
# 5208          Denim Bottoms    B171-DST
# 9746      Non-Denim Bottoms     B01-BRN
# 7509      Non-Denim Bottoms  102291-039
# 11243     Non-Denim Bottoms    B159-DKB
# 24071     Jackets/Pullovers    J140-BLK
#
#                                         Style Dimension ProductSize   Volume  \
# 3258                      M Acrylic Watch Hat                   OFA   61.640
# 2726                             M Odessa Cap                   OFA   96.000
# 15864            M Workwear Pocket SS T Shirt       REG         LRG   97.660
# 3266                      M Acrylic Watch Hat                   OFA   44.110
# 15866            M Workwear Pocket SS T Shirt       REG         MED   96.170
# 15870            M Workwear Pocket SS T Shirt       REG         XLG  105.840
# 16031            M Workwear Pocket SS T Shirt       REG         LRG  113.500
# 16037            M Workwear Pocket SS T Shirt       REG         XLG  128.430
# 15987            M Workwear Pocket SS T Shirt       REG         LRG  100.270
# 2724                             M Odessa Cap                   OFA   96.000
# 3244                      M Acrylic Watch Hat                   OFA   41.150
# 15993            M Workwear Pocket SS T Shirt       REG         XLG  114.150
# 2717                            M Buffalo Cap                   OFA   96.000
# 2730                             M Odessa Cap                   OFA   96.000
# 3264                      M Acrylic Watch Hat                   OFA   46.870
# 15868            M Workwear Pocket SS T Shirt       REG         SML   92.330
# 15872            M Workwear Pocket SS T Shirt       REG         XXL  116.610
# 2743                            M Dunmore Cap                   OFA   96.000
# 15949            M Workwear Pocket SS T Shirt       REG         XLG  109.530
# 15943            M Workwear Pocket SS T Shirt       REG         LRG   96.030
# 16033            M Workwear Pocket SS T Shirt       REG         MED  100.120
# 16039            M Workwear Pocket SS T Shirt       REG         XXL  121.410
# 16059            M Workwear Pocket SS T Shirt       REG         XLG  110.190
# 3274                      M Acrylic Watch Hat                   OFA   45.170
# 15989            M Workwear Pocket SS T Shirt       REG         MED   80.220
# 16053            M Workwear Pocket SS T Shirt       REG         LRG   93.750
# 13506       M Force Cotton Delmont SS T Shirt       REG         L     63.200
# 13512       M Force Cotton Delmont SS T Shirt       REG         XL    78.150
# 3272                      M Acrylic Watch Hat                   OFA   41.760
# 15892            M Workwear Pocket SS T Shirt       REG         XLG   98.350
# ...                                       ...       ...         ...      ...
# 27716                   M FR Canvas Shirt Jac       REG         L    382.000
# 14027             M Maddock Pocket SS T Shirt       REG         XL   101.110
# 16483  M RD Paxton HW Hdd Zip Mock Sweatshirt       REG         2XL  573.280
# 32295    W Crawford Double Front Bib Overalls       REG         L    253.170
# 8084     M Rugged Flex Rigby Five Pocket Pant        32          36  208.310
# 9668      M Firm Duck Dbl Front Work Dungaree        32          42  355.640
# 16245          M Signature Logo MW Sweatshirt       REG         M    449.000
# 24283                         M Sierra Jacket       REG         XLG 1254.790
# 4356      M Rugged Flex Relaxed Straight Jean        30          33  202.010
# 13343    M Workwear Pocket Sleeveless T Shirt       REG         4XL   99.640
# 17091                  M MW Hooded Sweatshirt       TLL         LRG  461.850
# 11500                 M Canvas Carpenter Jean        30          34  168.060
# 21521                M Sandstone Bib Overalls        30          34  332.290
# 24255                         M Sierra Jacket       REG         MED 1038.040
# 10174             M Washed Duck Work Dungaree        30          30  204.160
# 16767      M MW Canada Logo Sleeve Sweatshirt       REG         L    649.990
# 31287        W RF Original Fit Crawford Short                    12   95.750
# 15343      M Signature Sleeve Logo LS T Shirt       TLL         XXL  157.660
# 4203                M Straight Fit Elton Jean        30          32  172.590
# 14228              M Force Extremes SS Tshirt       REG         3XL   85.940
# 22862                            M Yukon Coat       REG         XLG 1566.290
# 5382           M Relaxed Fit Tapered Leg Jean        36          38  241.880
# 24876                        M Mock Neck Vest       REG         MED  483.640
# 10960                  M Canvas Work Dungaree        34          34  161.820
# 25150                 M FR Utility Denim Jean        30          34  232.260
# 5208             M Relaxed Fit Carpenter Jean        30          38  261.520
# 9746      M Firm Duck Dbl Front Work Dungaree        32          31  222.190
# 7509             M Rugged Flex Rigby Dungaree        34          33  173.690
# 11243                 M Canvas Carpenter Jean        32          34  211.320
# 24071                   M QFL Duck Active Jac       REG         3XL 1932.730
#
#       InventorySegment  ... NewProduct   Contract Future_Contract  Popularity  \
# 3258                 A  ...          0 113485.000      187848.000      23.853
# 2726                 A  ...          0  52985.000      108944.000      96.171
# 15864                A  ...          0  50067.000       69855.000      67.825
# 3266                 A  ...          0  55345.000       70819.000     -77.386
# 15866                A  ...          0  42451.000       59228.000      67.445
# 15870                A  ...          0  44490.000       62072.000      52.058
# 16031                A  ...          0  45329.000       58606.000      15.386
# 16037                A  ...          0  44535.000       57582.000      10.723
# 15987                A  ...          0  42376.000       57263.000      37.786
# 2724                 A  ...          0  35509.000       74841.000      56.325
# 3244                 A  ...          0  36741.000       49130.000      67.618
# 15993                A  ...          0  39637.000       53560.000      40.739
# 2717                 A  ...          0  42164.000       51671.000     -30.594
# 2730                 A  ...          0  36860.000       61791.000      52.061
# 3264                 A  ...          0  31140.000       60189.000     159.086
# 15868                A  ...          0  24090.000       33611.000     103.673
# 15872                A  ...          0  30055.000       41934.000      49.168
# 2743                 A  ...          0  32940.000       46682.000       0.413
# 15949                A  ...          0  31227.000       39355.000      14.641
# 15943                A  ...          0  32385.000       40813.000      -7.364
# 16033                A  ...          0  30880.000       39926.000      20.824
# 16039                A  ...          0  29852.000       38598.000      25.724
# 16059                A  ...          0  32133.000       41445.000     -21.436
# 3274                 A  ...          0  33369.000       52361.000     -54.735
# 15989                A  ...          0  28174.000       38069.000      47.418
# 16053                A  ...          0  31831.000       41058.000     -42.030
# 13506                A  ...          0  32202.000       38340.000     -72.884
# 13512                A  ...          0  31737.000       37787.000     -67.156
# 3272                 A  ...          0  39148.000       47116.000    -124.514
# 15892                A  ...          0  29225.000       36581.000     -39.778
# ...                ...  ...        ...        ...             ...         ...
# 27716                A  ...          0    873.000        1163.000     -58.392
# 14027                A  ...          0   2287.000         379.000    -915.821
# 16483                A  ...          0    753.000        1109.000     107.856
# 32295                A  ...          0    692.000         944.000     162.198
# 8084                 A  ...          0    983.000        1516.000     -45.406
# 9668                 A  ...          0   1043.000         851.000     -71.014
# 16245                A  ...          1    135.000           0.000     173.581
# 24283                A  ...          0    796.000         986.000      75.100
# 4356                 A  ...          0    765.000        1180.000     108.404
# 13343                A  ...          0    913.000         882.000     -39.525
# 17091                A  ...          0    564.000        2070.000     189.300
# 11500                A  ...          0    930.000         887.000    -861.381
# 21521                A  ...          0    736.000         692.000     100.429
# 24255                A  ...          0    785.000         328.000      40.849
# 10174                A  ...          0    895.000         827.000      30.771
# 16767                A  ...          0   2183.000         148.000    -961.260
# 31287                A  ...          0   1179.000        1076.000    -450.739
# 15343                A  ...          0    977.000        1667.000    -344.533
# 4203                 A  ...          0   1024.000        1117.000     -55.116
# 14228                A  ...          1    764.000         417.000     167.565
# 22862                A  ...          0    916.000         809.000     -16.751
# 5382                 A  ...          0    885.000         945.000      20.974
# 24876                A  ...          0   1024.000         463.000       0.147
# 10960                A  ...          0    864.000         810.000    -822.434
# 25150                A  ...          0   1041.000         632.000     -93.302
# 5208                 A  ...          0    901.000         789.000      26.999
# 9746                 A  ...          0   1010.000         890.000     -53.223
# 7509                 A  ...          0    770.000        1146.000     112.648
# 11243                A  ...          0    889.000         812.000    -121.898
# 24071                A  ...          0    805.000         542.000      68.990
#
#          Orders  Ordered_Units  Avg_Daily_Ordered_Units  Days_Ordered  \
# 3258  10876.000     123524.000                  771.000       164.000
# 2726  22204.000      65879.000                  409.833       164.000
# 15864 18765.000      58728.000                  365.500       164.000
# 3266   7409.000      51174.000                  318.000       163.000
# 15866 14188.000      50972.000                  311.500       164.000
# 15870 19694.000      49894.000                  314.333       164.000
# 16031 19134.000      46168.000                  288.333       164.000
# 16037 19995.000      45102.000                  282.167       164.000
# 15987 21430.000      45101.000                  281.333       164.000
# 2724   8183.000      43091.000                  261.833       164.000
# 3244   6082.000      42769.000                  266.667       162.000
# 15993 20683.000      42564.000                  265.833       164.000
# 2717  16569.000      41982.000                  263.500       164.000
# 2730  16229.000      40512.000                  251.667       164.000
# 3264   4734.000      38364.000                  240.500       164.000
# 15868  4897.000      35727.000                  212.167       163.000
# 15872 16548.000      34125.000                  215.667       164.000
# 2743  11283.000      33757.000                  212.500       161.000
# 15949 15521.000      31876.000                  199.167       164.000
# 15943 14591.000      31809.000                  198.000       164.000
# 16033 12876.000      31502.000                  195.833       164.000
# 16039 16126.000      31370.000                  196.000       164.000
# 16059 19127.000      30996.000                  193.333       164.000
# 3274   2844.000      30711.000                  193.667       160.000
# 15989 15610.000      30273.000                  187.500       164.000
# 16053 18158.000      29974.000                  187.167       164.000
# 13506 12129.000      28554.000                  176.333       163.000
# 13512 12180.000      28440.000                  175.500       163.000
# 3272   2725.000      27254.000                  169.000       161.000
# 15892 15585.000      27130.000                  169.333       164.000
# ...         ...            ...                      ...           ...
# 27716   495.000        965.000                   10.167        97.000
# 14027    96.000        965.000                   26.167        58.000
# 16483   503.000        964.000                    6.833       123.000
# 32295   391.000        964.000                    8.333       119.000
# 8084    554.000        964.000                    6.833       132.000
# 9668    754.000        963.000                    6.833       135.000
# 16245     2.000        963.000                  481.500         2.000
# 24283   629.000        962.000                    6.667       108.000
# 4356    644.000        962.000                    6.333       146.000
# 13343   451.000        962.000                    8.000       112.000
# 17091   469.000        961.000                    7.000       124.000
# 11500   362.000        961.000                   15.333        55.000
# 21521   760.000        961.000                    6.833       132.000
# 24255   532.000        961.000                    6.833       116.000
# 10174   564.000        961.000                    6.667       138.000
# 16767   762.000        960.000                   34.833        31.000
# 31287   491.000        960.000                   10.667        94.000
# 15343   549.000        960.000                    7.000       128.000
# 4203    574.000        958.000                    6.167       144.000
# 14228   670.000        958.000                    9.000       103.000
# 22862   537.000        958.000                    7.167       106.000
# 5382    588.000        956.000                    6.167       147.000
# 24876   484.000        956.000                    7.167       123.000
# 10960   296.000        955.000                    7.667       112.000
# 25150   333.000        955.000                    7.500       124.000
# 5208    437.000        955.000                    6.833       136.000
# 9746    634.000        954.000                    6.167       146.000
# 7509    699.000        953.000                    6.167       148.000
# 11243   690.000        953.000                   20.833        45.000
# 24071   524.000        952.000                    7.167       103.000
#
#        Order_Volume  Avg_Daily_Volume
# 3258    7614016.000         47546.667
# 2726    6324384.000         39393.833
# 15864   5735374.000         35734.333
# 3266    2257281.000         14051.667
# 15866   4901974.000         30020.500
# 15870   5280777.000         33315.667
# 16031   5240068.000         32801.167
# 16037   5792447.000         36299.500
# 15987   4522274.000         28271.500
# 2724    4136736.000         25180.333
# 3244    1759942.000         10987.833
# 15993   4858678.000         30393.167
# 2717    4030272.000         25336.000
# 2730    3889152.000         24207.500
# 3264    1798118.000         11293.667
# 15868   3298670.000         19635.000
# 15872   3979313.000         25217.833
# 2743    3240672.000         20440.667
# 15949   3491376.000         21840.000
# 15943   3054614.000         19053.333
# 16033   3153978.000         19643.500
# 16039   3808629.000         23860.833
# 16059   3415447.000         21356.333
# 3274    1387213.000          8772.167
# 15989   2428497.000         15097.000
# 16053   2810061.000         17571.833
# 13506   1804610.000         11165.667
# 13512   2222583.000         13738.167
# 3272    1138124.000          7081.833
# 15892   2668233.000         16706.667
# ...             ...               ...
# 27716    368630.000          4069.000
# 14027     97568.000          2684.833
# 16483    552638.000          4153.833
# 32295    244054.000          2199.667
# 8084     200808.000          1525.333
# 9668     342478.000          2581.000
# 16245    432387.000        216193.500
# 24283   1207105.000          8882.500
# 4356     194331.000          1375.667
# 13343     95851.000           836.667
# 17091    443835.000          3420.000
# 11500    161503.000          2629.500
# 21521    319327.000          2402.167
# 24255    997553.000          7561.167
# 10174    196196.000          1419.000
# 16767    623988.000         23024.500
# 31287     91918.000          1100.000
# 15343    151351.000          1159.167
# 4203     165337.000          1156.167
# 14228     82328.000           811.333
# 22862   1500503.000         11799.667
# 5382     231234.000          1595.000
# 24876    462357.000          3688.167
# 10960    154535.000          1347.167
# 25150    221804.000          1838.500
# 5208     249749.000          1874.833
# 9746     211965.000          1477.667
# 7509     165524.000          1149.167
# 11243    201386.000          4510.500
# 24071   1839956.000         15152.167
#
# [2280 rows x 22 columns]

# %%
dfFall_Top80
# Out:
#        Experiment_Id           Department             Category  \
# 3259            6236                Men's          Accessories
# 3267            6240                Men's          Accessories
# 3245            6226                Men's          Accessories
# 3265            6239                Men's          Accessories
# 3275            6247                Men's          Accessories
# 3247            6227                Men's          Accessories
# 3263            6238                Men's          Accessories
# 3273            6245                Men's          Accessories
# 3287            6258                Men's          Accessories
# 3297            6264                Men's          Accessories
# 3320            6285                Men's          Accessories
# 3253            6231                Men's          Accessories
# 2727            5581                Men's          Accessories
# 3261            6237                Men's          Accessories
# 2725            5580                Men's          Accessories
# 3251            6229                Men's          Accessories
# 2731            5583                Men's          Accessories
# 3271            6242                Men's          Accessories
# 3269            6241                Men's          Accessories
# 3306            6271                Men's          Accessories
# 17413          25620                Men's     First Layer Tops
# 3289            6259                Men's          Accessories
# 3249            6228                Men's          Accessories
# 2712            5566                Men's          Accessories
# 17419          25623                Men's     First Layer Tops
# 3295            6262                Men's          Accessories
# 15865          23691                Men's     First Layer Tops
# 3225            6214                Men's          Accessories
# 16032          23886                Men's     First Layer Tops
# 3312            6280                Men's          Accessories
# ...              ...                  ...                  ...
# 6445            9649                Men's  First Layer Bottoms
# 11021          16207                Men's  First Layer Bottoms
# 11501          16461                Men's  First Layer Bottoms
# 22701          31885                Men's            Outerwear
# 16662          24523                Men's     First Layer Tops
# 6639            9751                Men's  First Layer Bottoms
# 14976          22843                Men's     First Layer Tops
# 15738          23563                Men's     First Layer Tops
# 14233          19973                Men's     First Layer Tops
# 30572          41219              Women's  First Layer Bottoms
# 13455          19152                Men's     First Layer Tops
# 16266          24325                Men's     First Layer Tops
# 23869          33537                Men's            Outerwear
# 14946          22800                Men's     First Layer Tops
# 22831          31950                Men's            Outerwear
# 25295          35355  Personal Protective  First Layer Bottoms
# 21344          31055                Men's            Outerwear
# 27011          37626  Personal Protective     First Layer Tops
# 24102          33660                Men's            Outerwear
# 6573            9717                Men's  First Layer Bottoms
# 11187          16297                Men's  First Layer Bottoms
# 8355           12437                Men's  First Layer Bottoms
# 15168          22985                Men's     First Layer Tops
# 4389            8103                Men's  First Layer Bottoms
# 32899          46940              Women's            Outerwear
# 23112          32163                Men's            Outerwear
# 10411          15898                Men's  First Layer Bottoms
# 5343            8904                Men's  First Layer Bottoms
# 13591          19242                Men's     First Layer Tops
# 25494          35458  Personal Protective  First Layer Bottoms
#
#                 SubCategory    Material  \
# 3259               Headwear     A18-BLK
# 3267               Headwear     A18-CLH
# 3245               Headwear     A18-019
# 3265               Headwear     A18-BRN
# 3275               Headwear     A18-NVY
# 3247               Headwear     A18-247
# 3263               Headwear     A18-BOG
# 3273               Headwear     A18-HGY
# 3287               Headwear    A202-BLK
# 3297               Headwear    A205-BLK
# 3320               Headwear    A267-BLK
# 3253               Headwear     A18-648
# 2727               Headwear  100289-211
# 3261               Headwear     A18-BLM
# 2725               Headwear  100289-001
# 3251               Headwear     A18-492
# 2731               Headwear  100289-301
# 3271               Headwear     A18-DKB
# 3269               Headwear     A18-DGR
# 3306               Headwear    A205-HGY
# 17413                Sweats    K288-BLK
# 3289               Headwear    A202-CHH
# 3249               Headwear     A18-303
# 2712               Headwear  100137-001
# 17419                Sweats    K288-BLK
# 3295               Headwear    A205-093
# 15865                 Knits     K87-BLK
# 3225               Headwear    A161-BLK
# 16032                 Knits     K87-NVY
# 3312               Headwear    A207-BLK
# ...                     ...         ...
# 6445          Lined Bottoms    B111-BLK
# 11021     Non-Denim Bottoms    B151-TAN
# 11501     Non-Denim Bottoms    B159-NVY
# 22701          Coats/Parkas    C003-DNY
# 16662                Sweats  101759-001
# 6639          Lined Bottoms    B172-DST
# 14976                 Knits    K126-WHT
# 15738                 Knits     K84-NVY
# 14233                 Knits  102960-083
# 30572     Non-Denim Bottoms  102080-011
# 13455                 Knits  100393-412
# 16266                Sweats  100614-001
# 23869     Jackets/Pullovers    J130-DKB
# 14946                 Knits    K126-PRT
# 22831          Coats/Parkas     C26-MOS
# 25295         Denim Bottoms  FRB100-DNM
# 21344  Bottoms/Bib Overalls     R03-BLK
# 27011                 Knits  100495-824
# 24102     Jackets/Pullovers    J140-BRN
# 6573          Lined Bottoms    B111-MOS
# 11187     Non-Denim Bottoms    B159-CHR
# 8355      Non-Denim Bottoms  102802-918
# 15168                 Knits    K195-306
# 4389          Denim Bottoms  102804-964
# 32899     Jackets/Pullovers   WJ141-032
# 23112     Jackets/Pullovers  101492-412
# 10411     Non-Denim Bottoms    B136-DKB
# 5343          Denim Bottoms     B17-DST
# 13591                 Knits  100410-316
# 25494         Denim Bottoms   FRB13-DNM
#
#                                           Style Dimension ProductSize  \
# 3259                        M Acrylic Watch Hat                   OFA
# 3267                        M Acrylic Watch Hat                   OFA
# 3245                        M Acrylic Watch Hat                   OFA
# 3265                        M Acrylic Watch Hat                   OFA
# 3275                        M Acrylic Watch Hat                   OFA
# 3247                        M Acrylic Watch Hat                   OFA
# 3263                        M Acrylic Watch Hat                   OFA
# 3273                        M Acrylic Watch Hat                   OFA
# 3287                   M Fleece 2 in 1 Headwear                   OFA
# 3297                         M Acrylic Knit Hat                   OFA
# 3320                  M Force Helmet Liner Mask                   OFA
# 3253                        M Acrylic Watch Hat                   OFA
# 2727                               M Odessa Cap                   OFA
# 3261                        M Acrylic Watch Hat                   OFA
# 2725                               M Odessa Cap                   OFA
# 3251                        M Acrylic Watch Hat                   OFA
# 2731                               M Odessa Cap                   OFA
# 3271                        M Acrylic Watch Hat                   OFA
# 3269                        M Acrylic Watch Hat                   OFA
# 3306                         M Acrylic Knit Hat                   OFA
# 17413      M MW Signature Sleeve Logo Hdd Swtsh       REG         LRG
# 3289                   M Fleece 2 in 1 Headwear                   OFA
# 3249                        M Acrylic Watch Hat                   OFA
# 2712                M Greenfield Reversible Hat                   OFA
# 17419      M MW Signature Sleeve Logo Hdd Swtsh       REG         XLG
# 3295                         M Acrylic Knit Hat                   OFA
# 15865              M Workwear Pocket SS T Shirt       REG         LRG
# 3225                                M Face Mask                   OFA
# 16032              M Workwear Pocket SS T Shirt       REG         LRG
# 3312                               M Fleece Hat                   OFA
# ...                                         ...       ...         ...
# 6445       M Washed Duck Work Dng Flannel Lined        32          38
# 11021                    M Canvas Work Dungaree        32          33
# 11501                   M Canvas Carpenter Jean        30          34
# 22701                   M Duck Traditional Coat       REG         XXL
# 16662                 M Wind Fighter Sweatshirt       REG         L
# 6639   M Relaxed Fit Straight Leg Flannel Lined        30          44
# 14976              M Workwear Pocket LS T Shirt       REG         SML
# 15738               M Workwear Pocket SS Henley       TLL         XXL
# 14233                M Force Extremes SS Tshirt       REG         L
# 30572           W RF Original Fit Crawford Pant       REG          10
# 13455         M Force Cotton Delmont LS T Shirt       TLL         XL
# 16266    M RD Paxton HW Hdd Zip Frnt Sweatshirt       REG         3XL
# 23869                M QFL Sandstone Active Jac       REG         3XL
# 14946              M Workwear Pocket LS T Shirt       REG         3XL
# 22831              M Sandstone Traditional Coat       REG         MED
# 25295                 M FR Signature Denim Jean        32          34
# 21344    M Arctic Quilt Lined Duck Bib Overalls        34          34
# 27011                 M HV Force SS Class 2 Tee       REG         M
# 24102                     M QFL Duck Active Jac       REG         4XL
# 6573       M Washed Duck Work Dng Flannel Lined        32          32
# 11187                   M Canvas Carpenter Jean        34          32
# 8355           M Rugged Flex Rigby Double Front        34          36
# 15168               M Signature Logo SS T Shirt       REG         MED
# 4389        M Rugged Flex Relaxed Straight Jean        32          42
# 32899                           W Sierra Jacket       REG         LRG
# 23112    M Quick Duck Jefferson Traditional Jkt       REG         L
# 10411     M Washed Duck Dbl Front Work Dungaree        30          38
# 5343             M Relaxed Fit Tapered Leg Jean        32          46
# 13591         M Force Cotton Delmont SS T Shirt       REG         3XL
# 25494             M FR Signature Denim Dungaree        30          42
#
#         Volume InventorySegment  ... NewProduct   Contract Future_Contract  \
# 3259    61.640                A  ...          0 560967.000      787324.000
# 3267    44.110                A  ...          0 330940.000      436001.000
# 3245    41.150                A  ...          0 283116.000      372239.000
# 3265    46.870                A  ...          0 238883.000      337811.000
# 3275    45.170                A  ...          0 154798.000      217011.000
# 3247    47.030                A  ...          0 168876.000      209225.000
# 3263    57.230                A  ...          0 132084.000      192775.000
# 3273    41.760                A  ...          0  96157.000      115960.000
# 3287    96.000                A  ...          0 113442.000      145855.000
# 3297    30.940                A  ...          0 116663.000      136211.000
# 3320    72.758                A  ...          0 102351.000      129515.000
# 3253    55.740                A  ...          1  79451.000      106234.000
# 2727    96.000                A  ...          0  75335.000       88510.000
# 3261    47.060                A  ...          0  67116.000       81583.000
# 2725    96.000                A  ...          0  53973.000       55221.000
# 3251    55.740                A  ...          1  71086.000      113764.000
# 2731    96.000                A  ...          0  71628.000       48421.000
# 3271    44.540                A  ...          0  56088.000      115700.000
# 3269    49.350                A  ...          0  45592.000       48339.000
# 3306    30.030                A  ...          0  54634.000       74908.000
# 17413  478.540                A  ...          0  52780.000       58357.000
# 3289    62.660                A  ...          0  52282.000       62242.000
# 3249    55.740                A  ...          1  48367.000       60129.000
# 2712    53.720                A  ...          0  51762.000       26683.000
# 17419  523.300                A  ...          0  42677.000       47189.000
# 3295    29.680                A  ...          0  38827.000       38240.000
# 15865   97.660                A  ...          0  47399.000       62859.000
# 3225    85.540                A  ...          0  49804.000       49197.000
# 16032  113.500                A  ...          0  43246.000       51346.000
# 3312    43.920                A  ...          0  44769.000       45824.000
# ...        ...              ...  ...        ...        ...             ...
# 6445   278.650                A  ...          0   2085.000        1604.000
# 11021  174.990                A  ...          0   1360.000        1414.000
# 11501  168.060                A  ...          0   1053.000         961.000
# 22701 1719.470                A  ...          0   1666.000         907.000
# 16662    0.000                A  ...          0      0.000           0.000
# 6639   343.290                A  ...          0   1364.000        1123.000
# 14976  100.560                A  ...          0   1033.000         321.000
# 15738  127.500                A  ...          0   2117.000        1823.000
# 14233   77.690                A  ...          1   2912.000         436.000
# 30572  160.960                A  ...          0   1253.000        1423.000
# 13455  110.320                A  ...          0   1454.000        1460.000
# 16266  562.000                A  ...          0   1635.000        2089.000
# 23869 1489.680                A  ...          0   1381.000        1126.000
# 14946  149.210                A  ...          0   1894.000        1659.000
# 22831 1203.020                A  ...          0   1484.000         797.000
# 25295  242.000                A  ...          0   1846.000        1184.000
# 21344 1382.400                A  ...          0   1363.000        1180.000
# 27011   91.840                A  ...          0   1817.000        1815.000
# 24102 1859.400                A  ...          0   1304.000        1620.000
# 6573   265.930                A  ...          0   2274.000        1804.000
# 11187  179.700                A  ...          0   1566.000         984.000
# 8355   283.760                A  ...          0   2509.000        2677.000
# 15168  108.000                A  ...          1   2134.000        2191.000
# 4389   203.800                A  ...          0   2014.000        1761.000
# 32899  917.850                A  ...          0   2070.000        2157.000
# 23112  627.280                A  ...          0   1319.000         938.000
# 10411  200.220                A  ...          0   1679.000        1396.000
# 5343   302.870                A  ...          0   1447.000        1375.000
# 13591   92.650                A  ...          0   2468.000        2327.000
# 25494  245.120                A  ...          0   1684.000        1574.000
#
#        Popularity    Orders  Ordered_Units  Avg_Daily_Ordered_Units  \
# 3259      117.042 38155.000     756043.000                 4202.167
# 3267       12.053 28854.000     375921.000                 2088.333
# 3245        5.840 22336.000     290703.000                 1620.167
# 3265       14.822 18108.000     257305.000                 1427.000
# 3275      116.327 11454.000     199654.000                 1109.833
# 3247     -115.067 15200.000     155954.000                  903.000
# 3263      -58.211 13487.000     145171.000                  811.333
# 3273      117.233  7912.000     139181.000                  795.333
# 3287      -65.475 15500.000     121415.000                  675.833
# 3297      -84.598  9596.000     115862.000                  641.333
# 3320     -116.063 11337.000      96958.000                  539.333
# 3253       94.794  7842.000      90747.000                  516.667
# 2727       34.318 22957.000      88865.000                  493.667
# 3261       80.324  8924.000      83556.000                  471.333
# 2725      -40.804  7373.000      77366.000                  432.500
# 3251        5.844  7236.000      74112.000                  424.000
# 2731     -107.074 16872.000      68624.000                  380.500
# 3271       35.619  6042.000      63032.000                  353.000
# 3269      111.381  5382.000      62775.000                  350.833
# 3306       76.138  6649.000      60666.000                  353.167
# 17413     -16.171 12760.000      55212.000                  306.667
# 3289      -83.969  6144.000      54052.000                  308.167
# 3249      -50.544  4393.000      51283.000                  301.500
# 2712     -115.690  8922.000      49769.000                  284.333
# 17419      11.286 11107.000      47031.000                  261.167
# 3295       77.618  4032.000      46533.000                  274.667
# 15865     -53.197 16516.000      44697.000                  247.833
# 3225     -126.136  5450.000      44560.000                  256.333
# 16032     -12.593 16098.000      42261.000                  234.333
# 3312      -85.364  3731.000      42174.000                  245.000
# ...           ...       ...            ...                      ...
# 6445     -516.392   812.000       1452.000                   10.000
# 11021     -13.809   481.000       1451.000                    9.000
# 11501     170.026   687.000       1450.000                   14.500
# 22701    -276.170   370.000       1449.000                   13.167
# 16662     200.000     2.000       1449.000                  724.500
# 6639       -9.795   647.000       1449.000                   10.000
# 14976      12.677   408.000       1448.000                   10.667
# 15738    -288.516   803.000       1446.000                    7.833
# 14233    -922.229   773.000       1445.000                    8.167
# 30572     -17.631   567.000       1444.000                    8.500
# 13455     -71.555   892.000       1444.000                    9.333
# 16266    -205.898   855.000       1443.000                    8.167
# 23869      -4.058  1223.000       1441.000                    9.500
# 14946    -463.031   636.000       1439.000                   10.167
# 22831    -240.074   796.000       1439.000                    8.167
# 25295    -229.015   467.000       1439.000                    8.333
# 21344    -137.263   933.000       1438.000                    9.000
# 27011    -271.995   492.000       1438.000                    8.833
# 24102      -9.217  1022.000       1437.000                    8.833
# 6573     -798.980   782.000       1437.000                    9.000
# 11187     -82.435   744.000       1436.000                   10.500
# 8355     -534.726  1018.000       1434.000                   10.000
# 15168    -430.120   667.000       1433.000                   10.167
# 4389     -280.294   915.000       1432.000                    8.000
# 32899    -587.460   523.000       1432.000                    8.833
# 23112    -229.316   644.000       1431.000                    8.667
# 10411    -112.944   968.000       1431.000                    8.000
# 5343      -98.415   688.000       1430.000                    8.167
# 13591    -507.861   918.000       1430.000                    8.000
# 25494    -188.067   448.000       1430.000                    9.000
#
#        Days_Ordered  Order_Volume  Avg_Daily_Volume
# 3259        180.000  46602488.000        259045.000
# 3267        180.000  16581872.000         92137.667
# 3245        179.000  11962425.000         66683.667
# 3265        180.000  12059882.000         66905.333
# 3275        180.000   9018368.000         50149.667
# 3247        171.000   7334513.000         42488.333
# 3263        178.000   8308134.000         46445.500
# 3273        176.000   5812195.000         33239.333
# 3287        176.000  11655840.000         64931.667
# 3297        179.000   3584767.000         19862.667
# 3320        176.000   7054467.000         39287.667
# 3253        173.000   5058233.000         28826.167
# 2727        180.000   8531040.000         47424.333
# 3261        174.000   3932143.000         22203.500
# 2725        178.000   7427136.000         41577.167
# 3251        172.000   4131000.000         23669.667
# 2731        180.000   6587904.000         36582.833
# 3271        177.000   2807442.000         15742.667
# 3269        179.000   3097944.000         17333.000
# 3306        170.000   1821797.000         10612.667
# 17413       180.000  26421147.000        146958.167
# 3289        169.000   3386894.000         19338.833
# 3249        171.000   2858511.000         16835.333
# 2712        169.000   2673588.000         15294.333
# 17419       180.000  24611320.000        136886.667
# 3295        169.000   1381096.000          8160.333
# 15865       180.000   4365106.000         24260.000
# 3225        171.000   3811659.000         21969.000
# 16032       180.000   4796622.000         26662.000
# 3312        168.000   1852279.000         10780.500
# ...             ...           ...               ...
# 6445        135.000    404597.000          2853.500
# 11021       150.000    253908.000          1699.667
# 11501       100.000    243684.000          2514.500
# 22701       116.000   2491509.000         23289.500
# 16662         2.000         0.000             0.000
# 6639        131.000    497424.000          3592.833
# 14976       127.000    145607.000          1114.500
# 15738       171.000    184362.000          1074.167
# 14233       161.000    112258.000           661.667
# 30572       160.000    232422.000          1453.333
# 13455       147.000    159299.000          1094.833
# 16266       160.000    810966.000          4909.333
# 23869       144.000   2146625.000         14951.167
# 14946       151.000    214711.000          1594.500
# 22831       152.000   1731143.000         10635.000
# 25295       160.000    348238.000          2126.000
# 21344       137.000   1987888.000         13153.167
# 27011       142.000    132063.000           858.167
# 24102       147.000   2671956.000         17292.167
# 6573        142.000    382139.000          2506.000
# 11187       133.000    258047.000          1976.000
# 8355        138.000    406909.000          2956.833
# 15168       138.000    154764.000          1164.500
# 4389        161.000    291839.000          1787.500
# 32899       144.000   1314358.000          8517.333
# 23112       148.000    897636.000          5805.000
# 10411       168.000    286511.000          1694.833
# 5343        161.000    433101.000          2605.500
# 13591       170.000    132486.000           775.833
# 25494       149.000    350519.000          2320.167
#
# [2548 rows x 22 columns]

# %% [markdown]
# ### Data Transformation and Visualization

# %%
# dataSpring = dfSpring_Top80[['Volume', 'Orders', 'Ordered_Units', 'Avg_Daily_Ordered_Units', 'Days_Ordered', 'Order_Volume', 'Avg_Daily_Volume']]

# # Data Normalization
# data_normed_Spring = normalize(dataSpring)
# data_normed_Spring = pd.DataFrame(data_normed_Spring, columns=dataSpring.columns)

# # Data Standard Scaler
# # Create scaler
# scaler = preprocessing.StandardScaler()
# # Transform the feature
# data_scaled_Spring = scaler.fit_transform(dataSpring)
# data_scaled_Spring = pd.DataFrame(data_scaled_Spring, columns=dataSpring.columns)

# Plot Histograms for Raw Data, Normalized Data and Standard-Scaled Data
# plot_Histograms(dataSpring)
# plot_Histograms(data_normed_Spring)
# plot_Histograms(data_scaled_Spring)

# KSTest and QQPlots for Raw Data, Normalized Data and Standard-Scaled Data
# ksTest_QQPlots(dataSpring)
# ksTest_QQPlots(data_normed_Spring)
# ksTest_QQPlots(data_scaled_Spring)

# %%
# dataFall = dfFall_Top80[['Volume', 'Orders', 'Ordered_Units', 'Avg_Daily_Ordered_Units', 'Days_Ordered', 'Order_Volume', 'Avg_Daily_Volume']]

# # Data normalization
# data_normed_Fall = normalize(dataFall)
# data_normed_Fall = pd.DataFrame(data_normed_Fall, columns=dataFall.columns)

# # Data Standard Scaler
# # Create scaler
# scaler = preprocessing.StandardScaler()
# # Transform the feature
# data_scaled_Fall = scaler.fit_transform(dataFall)
# data_scaled_Fall = pd.DataFrame(data_scaled_Fall, columns=dataFall.columns)

# Plot Histograms for Raw Data, Normalized Data and Standard-Scaled Data
# plot_Histograms(dataFall)
# plot_Histograms(data_normed_Fall)
# plot_Histograms(data_scaled_Fall)

# KSTest and QQPlots for Raw Data, Normalized Data and Standard-Scaled Data
# ksTest_QQPlots(dataFall)
# ksTest_QQPlots(data_normed_Fall)
# ksTest_QQPlots(data_scaled_Fall)

# %% [markdown]
# ### Feature Selection for Clustering

# %%
CLUSTERING_FEATURE_SET_1 = ['Volume', 'Orders', 'Ordered_Units', 'Days_Ordered', 'Order_Volume']
CLUSTERING_FEATURE_SET_2 = ['Volume', 'Orders', 'Avg_Daily_Ordered_Units', 'Days_Ordered', 'Order_Volume']
CLUSTERING_FEATURE_SET_3 = ['Volume', 'Orders', 'Ordered_Units', 'Days_Ordered', 'Avg_Daily_Volume']
CLUSTERING_FEATURE_SET_4 = ['Volume', 'Orders', 'Avg_Daily_Ordered_Units', 'Days_Ordered', 'Avg_Daily_Volume']
CLUSTERING_FEATURE_SET_5 = ['Future_Contract', 'Popularity', 'Avg_Daily_Ordered_Units']

CLUSTERING_FEATURE_SET = CLUSTERING_FEATURE_SET_4

dfSpring_clust = dfSpring_Top80[CLUSTERING_FEATURE_SET]
dfFall_clust = dfFall_Top80[CLUSTERING_FEATURE_SET]

# %%
# Bootstrap Resampling
# from sklearn.utils import resample
# # prepare bootstrap sample
# bootSpring = resample(dfSpring_clust, replace=True)
# bootFall = resample(dfFall_clust, replace=True)

# %% [markdown]
# ### Calculate Corelation of Selected Features

# %%
# corr_Spring = dfSpring_clust.corr()
# corr_Spring.style.background_gradient(cmap='coolwarm', axis=None)

# %%
# corr_Fall = dfFall_clust.corr()
# corr_Fall.style.background_gradient(cmap='coolwarm', axis=None)

# %% [markdown]
# ### Calculate 'p-value' of Corelation matrix

# %%
# # Find p-values (p) of Spring Corelation Matrix
# r, p = corrcoef_loop(corr_Spring.values)

# # Convert the p-value matrix into a dataframe for plotting
# p_df = pd.DataFrame(p)
# p_df.columns = CLUSTERING_FEATURE_SET
# p_df.index = CLUSTERING_FEATURE_SET

# p_df.style.background_gradient(cmap='coolwarm', axis=None)

# %%
# # Find p-values (p) of Fall Corelation Matrix
# r, p = corrcoef_loop(corr_Fall.values)

# # Convert the p-value matrix into a dataframe for plotting
# p_df = pd.DataFrame(p)
# p_df.columns = CLUSTERING_FEATURE_SET
# p_df.index = CLUSTERING_FEATURE_SET

# p_df.style.background_gradient(cmap='coolwarm', axis=None)

# %% [markdown]
# ### Calculate 'Confidence Interval' of clustering dataset

# %%
# # Calculate confidence interval of Spring dataset
# confInt_Spring =  pd.DataFrame(sms.DescrStatsW(dfSpring_clust).tconfint_mean(),
#                                columns=CLUSTERING_FEATURE_SET)
# print('\n----- Confidence interval of Spring dataset -----\n\n', confInt_Spring)

# # Calculate confidence interval of Fall dataset
# confInt_Fall = pd.DataFrame(sms.DescrStatsW(dfFall_clust).tconfint_mean(),
#                             columns=CLUSTERING_FEATURE_SET)
# print('\n----- Confidence interval of Fall dataset -----\n\n', confInt_Fall)

# %% [markdown]
# ### Agglomerative Clustering

# %%
# data = dfSpring_clust.copy()
# data_scaled = normalize(data)
# data_scaled = pd.DataFrame(data_scaled, columns=data.columns)

# plt.figure(figsize=(10, 7))  
# plt.title("Dendrograms")  
# dend = shc.dendrogram(shc.linkage(data_scaled, method='ward'))

# %%
# # Cluster Spring data by Agglomerative Clustering
# # Agglomerative with n=3
# cluster_label = Agglomerative_clusterLabels(data_scaled, 3)

# dfSpring_Top80['Agglo_Cluster3_Label'] = cluster_label
# print("\n----- Spring Cluster_Label counts with Agglomerative n=3 -----")
# print(dfSpring_Top80['Agglo_Cluster3_Label'].value_counts())

# # Clustering Accuracy : Calculate Silhouette Coefficient
# # Evaluate the cluster model for Spring data
# accuracySpring = silhouette_score(data_scaled, cluster_label)
# print("Accuracy of Agglomerative with n=3 on Spring data: ", accuracySpring)

# %%
# data = dfFall_clust.copy()
# data_scaled = normalize(data)
# data_scaled = pd.DataFrame(data_scaled, columns=data.columns)

# plt.figure(figsize=(10, 7))  
# plt.title("Dendrograms")  
# dend = shc.dendrogram(shc.linkage(data_scaled, method='ward'))

# %%
# # Cluster Fall data by Agglomerative Clustering
# # Agglomerative with n=3
# cluster_label = Agglomerative_clusterLabels(data_scaled, 3)

# dfFall_Top80['Agglo_Cluster3_Label'] = cluster_label
# print("\n----- Fall Cluster_Label counts with Agglomerative n=3 -----")
# print(dfFall_Top80['Agglo_Cluster3_Label'].value_counts())

# # Clustering Accuracy : Calculate Silhouette Coefficient
# # Evaluate the cluster model for Fall data
# accuracyFall = silhouette_score(data_scaled, cluster_label)
# print("Accuracy of Agglomerative with n=3 on Fall data: ", accuracyFall)

# %% [markdown]
# ### K-Means Clustering

# %%
# Cluster Spring by K-Means Clustering
# Kmeans with n=3 on Spring Data
spring_cluster3_label = KMeans_clusterLabels(dfSpring_clust, 3)
dfSpring_Top80['KMeans_Cluster3_Label'] = spring_cluster3_label

print("\n----- Spring Cluster_Label counts with KMeans n=3 -----")
print(dfSpring_Top80['KMeans_Cluster3_Label'].value_counts())

# Clustering Accuracy : Calculate Silhouette Coefficient
# Evaluate the 3-cluster model for Spring
accuracySpring = silhouette_score(dfSpring_clust, spring_cluster3_label)
print("Accuracy of KMeans with n=3 on Spring data: ", accuracySpring)

# Add binary response values for each Cluster Labels
dfSpring_Top80 = add_binary_response_Kmeans_clusterLabels(dfSpring_Top80)
# Out:
# ----- Spring Cluster_Label counts with KMeans n=3 -----
# 3    2193
# 2      80
# 1       7
# Name: KMeans_Cluster3_Label, dtype: int64
# Accuracy of KMeans with n=3 on Spring data:  0.8342666372524808

# %%
# Cluster Fall by K-Means Clustering
# Kmeans with n=3 on Fall Data
fall_cluster3_label = KMeans_clusterLabels(dfFall_clust, 3)
dfFall_Top80['KMeans_Cluster3_Label'] = fall_cluster3_label

print("\n----- Fall Cluster_Label counts with KMeans n=3 -----")
print(dfFall_Top80['KMeans_Cluster3_Label'].value_counts())

# Clustering Accuracy : Calculate Silhouette Coefficient
# Evaluate the 3-cluster model for Fall
accuracyFall = silhouette_score(dfFall_clust, fall_cluster3_label)
print("Accuracy of KMeans with n=3 on Fall data: ", accuracyFall)

# Add binary response values for each Cluster Labels
dfFall_Top80 = add_binary_response_Kmeans_clusterLabels(dfFall_Top80)
# Out:
# ----- Fall Cluster_Label counts with KMeans n=3 -----
# 3    2483
# 2      51
# 1      14
# Name: KMeans_Cluster3_Label, dtype: int64
# Accuracy of KMeans with n=3 on Fall data:  0.9080083963489669

# %%
# Create datasets for Classification (Spring and Fall)
dfSpring = create_Classification_Dataset(dfSpring_Top80)
print("Spring dataset shape: ", dfSpring.shape)
print("----- Feature Set ----- \n", list(dfSpring.columns))
print("\n")
dfFall = create_Classification_Dataset(dfFall_Top80)
print("Fall dataset shape: ", dfFall.shape)
print("----- Feature Set ----- \n", list(dfFall.columns))
# Out:
# Spring dataset shape:  (2280, 28)
# ----- Feature Set -----
#  ['Experiment_Id', 'Department', 'Category', 'SubCategory', 'Material', 'Style', 'Dimension', 'ProductSize', 'Volume', 'InventorySegment', 'Color', 'UPC', 'NewProduct', 'Contract', 'Future_Contract', 'Popularity', 'Orders', 'Ordered_Units', 'Avg_Daily_Ordered_Units', 'Days_Ordered', 'Order_Volume', 'Avg_Daily_Volume', 'KMeans_Cluster3_Label', 'Cluster_1', 'Cluster_2', 'Cluster_3', 'Suggested_Storage_Type', 'Class']
#
#
# Fall dataset shape:  (2548, 28)
# ----- Feature Set -----
#  ['Experiment_Id', 'Department', 'Category', 'SubCategory', 'Material', 'Style', 'Dimension', 'ProductSize', 'Volume', 'InventorySegment', 'Color', 'UPC', 'NewProduct', 'Contract', 'Future_Contract', 'Popularity', 'Orders', 'Ordered_Units', 'Avg_Daily_Ordered_Units', 'Days_Ordered', 'Order_Volume', 'Avg_Daily_Volume', 'KMeans_Cluster3_Label', 'Cluster_1', 'Cluster_2', 'Cluster_3', 'Suggested_Storage_Type', 'Class']

# %%
## Box-plots
# sns.boxplot(x='Suggested_Storage_Type', y='Avg_Daily_Volume', data=dfSpring, showfliers=False)
# sns.boxplot(x='Agglo_Cluster3_Label', y='Avg_Daily_Volume', data=dfSpring, showfliers=False)
# sns.boxplot(x='KMeans_Cluster3_Label', y='Avg_Daily_Volume', data=dfSpring, showfliers=False)
# sns.boxplot(x='Suggested_Storage_Type', y='Avg_Daily_Volume', data=dfFall, showfliers=False)
# sns.boxplot(x='Agglo_Cluster3_Label', y='Avg_Daily_Volume', data=dfFall, showfliers=False)
# sns.boxplot(x='KMeans_Cluster3_Label', y='Avg_Daily_Volume', data=dfFall, showfliers=False)

# %% [markdown]
# ### Classification - Multinomial Logistic Regression

# %% [markdown]
# #### Resampling data to have equal cluster labels

# %%
# Resampling SPRING Data

print(dfSpring['KMeans_Cluster3_Label'].value_counts())

# sampling size: mean of cluster label assignments
n_samples = np.mean(dfSpring['KMeans_Cluster3_Label'].value_counts())

# Separate majority and minority classes
dfSpring_clus1 = dfSpring[dfSpring['KMeans_Cluster3_Label']==1]
dfSpring_clus2 = dfSpring[dfSpring['KMeans_Cluster3_Label']==2]
dfSpring_clus3 = dfSpring[dfSpring['KMeans_Cluster3_Label']==3]

# Resample Cluster1 assignments
dfSpring_clus1_resampled = resample(dfSpring_clus1, 
                                     replace=True,             # sample with replacement
                                     n_samples=int(n_samples), # to match the mean of three cluster assignments
                                     random_state=123)         # reproducible results

# Resample Cluster2 assignments
dfSpring_clus2_resampled = resample(dfSpring_clus2, 
                                     replace=True,             # sample with replacement
                                     n_samples=int(n_samples), # to match the mean of three cluster assignments
                                     random_state=123)         # reproducible results

# Resample Cluster3 assignments
dfSpring_clus3_resampled = resample(dfSpring_clus3, 
                                     replace=False,            # sample without replacement
                                     n_samples=int(n_samples), # to match the mean of three cluster assignments
                                     random_state=123)         # reproducible results

# Combine the resampled classes
dfSpring_resampled = pd.concat([dfSpring_clus1_resampled, dfSpring_clus2_resampled, dfSpring_clus3_resampled])

print("\nResampled Spring dataset shape: ", dfSpring_resampled.shape)
print(dfSpring_resampled['KMeans_Cluster3_Label'].value_counts())
# Out:
# 3    2193
# 2      80
# 1       7
# Name: KMeans_Cluster3_Label, dtype: int64
#
# Resampled Spring dataset shape:  (2280, 28)
# 3    760
# 1    760
# 2    760
# Name: KMeans_Cluster3_Label, dtype: int64

# %%
print(dfSpring['Cluster_1'].value_counts())
print(dfSpring_resampled['Cluster_1'].value_counts())
print(dfSpring['Cluster_2'].value_counts())
print(dfSpring_resampled['Cluster_2'].value_counts())
print(dfSpring['Cluster_3'].value_counts())
print(dfSpring_resampled['Cluster_3'].value_counts())
# Out:
# 0    2273
# 1       7
# Name: Cluster_1, dtype: int64
# 0    1520
# 1     760
# Name: Cluster_1, dtype: int64
# 0    2200
# 1      80
# Name: Cluster_2, dtype: int64
# 0    1520
# 1     760
# Name: Cluster_2, dtype: int64
# 1    2193
# 0      87
# Name: Cluster_3, dtype: int64
# 0    1520
# 1     760
# Name: Cluster_3, dtype: int64

# %%
# Resampling FALL Data

print(dfFall['KMeans_Cluster3_Label'].value_counts())

# sampling size: mean of cluster label assignments
n_samples = np.mean(dfFall['KMeans_Cluster3_Label'].value_counts())

# Separate majority and minority classes
dfFall_clus1 = dfFall[dfFall['KMeans_Cluster3_Label']==1]
dfFall_clus2 = dfFall[dfFall['KMeans_Cluster3_Label']==2]
dfFall_clus3 = dfFall[dfFall['KMeans_Cluster3_Label']==3]

# Resample Cluster1 assignments
dfFall_clus1_resampled = resample(dfFall_clus1, 
                                     replace=True,             # sample with replacement
                                     n_samples=int(n_samples), # to match the mean of three cluster assignments
                                     random_state=123)         # reproducible results

# Resample Cluster2 assignments
dfFall_clus2_resampled = resample(dfFall_clus2, 
                                     replace=True,             # sample with replacement
                                     n_samples=int(n_samples), # to match the mean of three cluster assignments
                                     random_state=123)         # reproducible results

# Resample Cluster3 assignments
dfFall_clus3_resampled = resample(dfFall_clus3, 
                                     replace=False,            # sample without replacement
                                     n_samples=int(n_samples), # to match the mean of three cluster assignments
                                     random_state=123)         # reproducible results

# Combine the resampled classes
dfFall_resampled = pd.concat([dfFall_clus1_resampled, dfFall_clus2_resampled, dfFall_clus3_resampled])

print("\nResampled Spring dataset shape: ", dfFall_resampled.shape)
print(dfFall_resampled['KMeans_Cluster3_Label'].value_counts())
# Out:
# 3    2483
# 2      51
# 1      14
# Name: KMeans_Cluster3_Label, dtype: int64
#
# Resampled Spring dataset shape:  (2547, 28)
# 3    849
# 1    849
# 2    849
# Name: KMeans_Cluster3_Label, dtype: int64

# %%
print(dfFall['Cluster_1'].value_counts())
print(dfFall_resampled['Cluster_1'].value_counts())
print(dfFall['Cluster_2'].value_counts())
print(dfFall_resampled['Cluster_2'].value_counts())
print(dfFall['Cluster_3'].value_counts())
print(dfFall_resampled['Cluster_3'].value_counts())
# Out:
# 0    2534
# 1      14
# Name: Cluster_1, dtype: int64
# 0    1698
# 1     849
# Name: Cluster_1, dtype: int64
# 0    2497
# 1      51
# Name: Cluster_2, dtype: int64
# 0    1698
# 1     849
# Name: Cluster_2, dtype: int64
# 1    2483
# 0      65
# Name: Cluster_3, dtype: int64
# 0    1698
# 1     849
# Name: Cluster_3, dtype: int64

# %%
#Corelation matrix of Features: Spring Data
FEATURES =['Volume', 'NewProduct', 'Contract', 'Future_Contract', 'Popularity', 'Orders', 'Ordered_Units', 'Avg_Daily_Ordered_Units', 'Days_Ordered', 'Order_Volume', 'Avg_Daily_Volume']
corr_Spring = dfSpring_resampled[FEATURES].corr()
corr_Spring.style.background_gradient(cmap='coolwarm', axis=None)
# Out:
# <style  type="text/css" >
#     #T_36fcf086_d573_11e9_8e4b_605718ad0862row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_36fcf086_d573_11e9_8e4b_605718ad0862row0_col1 {
#             background-color:  #aec9fc;
#             color:  #000000;
#         }    #T_36fcf086_d573_11e9_8e4b_605718ad0862row0_col2 {
#             background-color:  #b2ccfb;
#             color:  #000000;
#         }    #T_36fcf086_d573_11e9_8e4b_605718ad0862row0_col3 {
#             background-color:  #d9dce1;
#             color:  #000000;
#         }    #T_36fcf086_d573_11e9_8e4b_605718ad0862row0_col4 {
#             background-color:  #a9c6fd;
#             color:  #000000;
#         }    #T_36fcf086_d573_11e9_8e4b_605718ad0862row0_col5 {
#             background-color:  #adc9fd;
#             color:  #000000;
#         }    #T_36fcf086_d573_11e9_8e4b_605718ad0862row0_col6 {
#             background-color:  #bad0f8;
#             color:  #000000;
#         }    #T_36fcf086_d573_11e9_8e4b_605718ad0862row0_col7 {
#             background-color:  #d8dce2;
#             color:  #000000;
#         }    #T_36fcf086_d573_11e9_8e4b_605718ad0862row0_col8 {
#             background-color:  #f7ba9f;
#             color:  #000000;
#         }    #T_36fcf086_d573_11e9_8e4b_605718ad0862row0_col9 {
#             background-color:  #ccd9ed;
#             color:  #000000;
#         }    #T_36fcf086_d573_11e9_8e4b_605718ad0862row1_col0 {
#             background-color:  #aec9fc;
#             color:  #000000;
#         }    #T_36fcf086_d573_11e9_8e4b_605718ad0862row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_36fcf086_d573_11e9_8e4b_605718ad0862row1_col2 {
#             background-color:  #b8122a;
#             color:  #f1f1f1;
#         }    #T_36fcf086_d573_11e9_8e4b_605718ad0862row1_col3 {
#             background-color:  #d7dce3;
#             color:  #000000;
#         }    #T_36fcf086_d573_11e9_8e4b_605718ad0862row1_col4 {
#             background-color:  #cd423b;
#             color:  #f1f1f1;
#         }    #T_36fcf086_d573_11e9_8e4b_605718ad0862row1_col5 {
#             background-color:  #b50927;
#             color:  #f1f1f1;
#         }    #T_36fcf086_d573_11e9_8e4b_605718ad0862row1_col6 {
#             background-color:  #b6cefa;
#             color:  #000000;
#         }    #T_36fcf086_d573_11e9_8e4b_605718ad0862row1_col7 {
#             background-color:  #f7ac8e;
#             color:  #000000;
#         }    #T_36fcf086_d573_11e9_8e4b_605718ad0862row1_col8 {
#             background-color:  #e9785d;
#             color:  #000000;
#         }    #T_36fcf086_d573_11e9_8e4b_605718ad0862row1_col9 {
#             background-color:  #9ebeff;
#             color:  #000000;
#         }    #T_36fcf086_d573_11e9_8e4b_605718ad0862row2_col0 {
#             background-color:  #b2ccfb;
#             color:  #000000;
#         }    #T_36fcf086_d573_11e9_8e4b_605718ad0862row2_col1 {
#             background-color:  #b8122a;
#             color:  #f1f1f1;
#         }    #T_36fcf086_d573_11e9_8e4b_605718ad0862row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_36fcf086_d573_11e9_8e4b_605718ad0862row2_col3 {
#             background-color:  #d8dce2;
#             color:  #000000;
#         }    #T_36fcf086_d573_11e9_8e4b_605718ad0862row2_col4 {
#             background-color:  #d85646;
#             color:  #000000;
#         }    #T_36fcf086_d573_11e9_8e4b_605718ad0862row2_col5 {
#             background-color:  #b70d28;
#             color:  #f1f1f1;
#         }    #T_36fcf086_d573_11e9_8e4b_605718ad0862row2_col6 {
#             background-color:  #bad0f8;
#             color:  #000000;
#         }    #T_36fcf086_d573_11e9_8e4b_605718ad0862row2_col7 {
#             background-color:  #f7af91;
#             color:  #000000;
#         }    #T_36fcf086_d573_11e9_8e4b_605718ad0862row2_col8 {
#             background-color:  #e9785d;
#             color:  #000000;
#         }    #T_36fcf086_d573_11e9_8e4b_605718ad0862row2_col9 {
#             background-color:  #a2c1ff;
#             color:  #000000;
#         }    #T_36fcf086_d573_11e9_8e4b_605718ad0862row3_col0 {
#             background-color:  #d9dce1;
#             color:  #000000;
#         }    #T_36fcf086_d573_11e9_8e4b_605718ad0862row3_col1 {
#             background-color:  #d7dce3;
#             color:  #000000;
#         }    #T_36fcf086_d573_11e9_8e4b_605718ad0862row3_col2 {
#             background-color:  #d8dce2;
#             color:  #000000;
#         }    #T_36fcf086_d573_11e9_8e4b_605718ad0862row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_36fcf086_d573_11e9_8e4b_605718ad0862row3_col4 {
#             background-color:  #d8dce2;
#             color:  #000000;
#         }    #T_36fcf086_d573_11e9_8e4b_605718ad0862row3_col5 {
#             background-color:  #d8dce2;
#             color:  #000000;
#         }    #T_36fcf086_d573_11e9_8e4b_605718ad0862row3_col6 {
#             background-color:  #dcdddd;
#             color:  #000000;
#         }    #T_36fcf086_d573_11e9_8e4b_605718ad0862row3_col7 {
#             background-color:  #dcdddd;
#             color:  #000000;
#         }    #T_36fcf086_d573_11e9_8e4b_605718ad0862row3_col8 {
#             background-color:  #dadce0;
#             color:  #000000;
#         }    #T_36fcf086_d573_11e9_8e4b_605718ad0862row3_col9 {
#             background-color:  #dddcdc;
#             color:  #000000;
#         }    #T_36fcf086_d573_11e9_8e4b_605718ad0862row4_col0 {
#             background-color:  #a9c6fd;
#             color:  #000000;
#         }    #T_36fcf086_d573_11e9_8e4b_605718ad0862row4_col1 {
#             background-color:  #cd423b;
#             color:  #f1f1f1;
#         }    #T_36fcf086_d573_11e9_8e4b_605718ad0862row4_col2 {
#             background-color:  #d85646;
#             color:  #000000;
#         }    #T_36fcf086_d573_11e9_8e4b_605718ad0862row4_col3 {
#             background-color:  #d8dce2;
#             color:  #000000;
#         }    #T_36fcf086_d573_11e9_8e4b_605718ad0862row4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_36fcf086_d573_11e9_8e4b_605718ad0862row4_col5 {
#             background-color:  #d1493f;
#             color:  #f1f1f1;
#         }    #T_36fcf086_d573_11e9_8e4b_605718ad0862row4_col6 {
#             background-color:  #aac7fd;
#             color:  #000000;
#         }    #T_36fcf086_d573_11e9_8e4b_605718ad0862row4_col7 {
#             background-color:  #f5a081;
#             color:  #000000;
#         }    #T_36fcf086_d573_11e9_8e4b_605718ad0862row4_col8 {
#             background-color:  #ee8468;
#             color:  #000000;
#         }    #T_36fcf086_d573_11e9_8e4b_605718ad0862row4_col9 {
#             background-color:  #96b7ff;
#             color:  #000000;
#         }    #T_36fcf086_d573_11e9_8e4b_605718ad0862row5_col0 {
#             background-color:  #adc9fd;
#             color:  #000000;
#         }    #T_36fcf086_d573_11e9_8e4b_605718ad0862row5_col1 {
#             background-color:  #b50927;
#             color:  #f1f1f1;
#         }    #T_36fcf086_d573_11e9_8e4b_605718ad0862row5_col2 {
#             background-color:  #b70d28;
#             color:  #f1f1f1;
#         }    #T_36fcf086_d573_11e9_8e4b_605718ad0862row5_col3 {
#             background-color:  #d8dce2;
#             color:  #000000;
#         }    #T_36fcf086_d573_11e9_8e4b_605718ad0862row5_col4 {
#             background-color:  #d1493f;
#             color:  #f1f1f1;
#         }    #T_36fcf086_d573_11e9_8e4b_605718ad0862row5_col5 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_36fcf086_d573_11e9_8e4b_605718ad0862row5_col6 {
#             background-color:  #bed2f6;
#             color:  #000000;
#         }    #T_36fcf086_d573_11e9_8e4b_605718ad0862row5_col7 {
#             background-color:  #f7b396;
#             color:  #000000;
#         }    #T_36fcf086_d573_11e9_8e4b_605718ad0862row5_col8 {
#             background-color:  #e97a5f;
#             color:  #000000;
#         }    #T_36fcf086_d573_11e9_8e4b_605718ad0862row5_col9 {
#             background-color:  #a5c3fe;
#             color:  #000000;

# %%
# Find p-values (p) of Spring Corelation Matrix
r, p = corrcoef_loop(corr_Spring.values)
p_df = pd.DataFrame(p, columns=corr_Spring.columns, index=corr_Spring.index)
p_df.style.background_gradient(cmap='coolwarm', axis=None)
# Out:
# <style  type="text/css" >
#     #T_371f38e2_d573_11e9_a914_605718ad0862row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_371f38e2_d573_11e9_a914_605718ad0862row0_col1 {
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }    #T_371f38e2_d573_11e9_a914_605718ad0862row0_col2 {
#             background-color:  #6e90f2;
#             color:  #000000;
#         }    #T_371f38e2_d573_11e9_a914_605718ad0862row0_col3 {
#             background-color:  #ba162b;
#             color:  #f1f1f1;
#         }    #T_371f38e2_d573_11e9_a914_605718ad0862row0_col4 {
#             background-color:  #6f92f3;
#             color:  #000000;
#         }    #T_371f38e2_d573_11e9_a914_605718ad0862row0_col5 {
#             background-color:  #6687ed;
#             color:  #000000;
#         }    #T_371f38e2_d573_11e9_a914_605718ad0862row0_col6 {
#             background-color:  #f6bfa6;
#             color:  #000000;
#         }    #T_371f38e2_d573_11e9_a914_605718ad0862row0_col7 {
#             background-color:  #be242e;
#             color:  #f1f1f1;
#         }    #T_371f38e2_d573_11e9_a914_605718ad0862row0_col8 {
#             background-color:  #d95847;
#             color:  #000000;
#         }    #T_371f38e2_d573_11e9_a914_605718ad0862row0_col9 {
#             background-color:  #dc5d4a;
#             color:  #000000;
#         }    #T_371f38e2_d573_11e9_a914_605718ad0862row1_col0 {
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }    #T_371f38e2_d573_11e9_a914_605718ad0862row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_371f38e2_d573_11e9_a914_605718ad0862row1_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_371f38e2_d573_11e9_a914_605718ad0862row1_col3 {
#             background-color:  #c5d6f2;
#             color:  #000000;
#         }    #T_371f38e2_d573_11e9_a914_605718ad0862row1_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_371f38e2_d573_11e9_a914_605718ad0862row1_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_371f38e2_d573_11e9_a914_605718ad0862row1_col6 {
#             background-color:  #4c66d6;
#             color:  #000000;
#         }    #T_371f38e2_d573_11e9_a914_605718ad0862row1_col7 {
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }    #T_371f38e2_d573_11e9_a914_605718ad0862row1_col8 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_371f38e2_d573_11e9_a914_605718ad0862row1_col9 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }    #T_371f38e2_d573_11e9_a914_605718ad0862row2_col0 {
#             background-color:  #6e90f2;
#             color:  #000000;
#         }    #T_371f38e2_d573_11e9_a914_605718ad0862row2_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_371f38e2_d573_11e9_a914_605718ad0862row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_371f38e2_d573_11e9_a914_605718ad0862row2_col3 {
#             background-color:  #c4d5f3;
#             color:  #000000;
#         }    #T_371f38e2_d573_11e9_a914_605718ad0862row2_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_371f38e2_d573_11e9_a914_605718ad0862row2_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_371f38e2_d573_11e9_a914_605718ad0862row2_col6 {
#             background-color:  #4e68d8;
#             color:  #000000;
#         }    #T_371f38e2_d573_11e9_a914_605718ad0862row2_col7 {
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }    #T_371f38e2_d573_11e9_a914_605718ad0862row2_col8 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_371f38e2_d573_11e9_a914_605718ad0862row2_col9 {
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }    #T_371f38e2_d573_11e9_a914_605718ad0862row3_col0 {
#             background-color:  #ba162b;
#             color:  #f1f1f1;
#         }    #T_371f38e2_d573_11e9_a914_605718ad0862row3_col1 {
#             background-color:  #c5d6f2;
#             color:  #000000;
#         }    #T_371f38e2_d573_11e9_a914_605718ad0862row3_col2 {
#             background-color:  #c4d5f3;
#             color:  #000000;
#         }    #T_371f38e2_d573_11e9_a914_605718ad0862row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_371f38e2_d573_11e9_a914_605718ad0862row3_col4 {
#             background-color:  #d4dbe6;
#             color:  #000000;
#         }    #T_371f38e2_d573_11e9_a914_605718ad0862row3_col5 {
#             background-color:  #c4d5f3;
#             color:  #000000;
#         }    #T_371f38e2_d573_11e9_a914_605718ad0862row3_col6 {
#             background-color:  #df634e;
#             color:  #000000;
#         }    #T_371f38e2_d573_11e9_a914_605718ad0862row3_col7 {
#             background-color:  #eb7d62;
#             color:  #000000;
#         }    #T_371f38e2_d573_11e9_a914_605718ad0862row3_col8 {
#             background-color:  #c5d6f2;
#             color:  #000000;
#         }    #T_371f38e2_d573_11e9_a914_605718ad0862row3_col9 {
#             background-color:  #ee8669;
#             color:  #000000;
#         }    #T_371f38e2_d573_11e9_a914_605718ad0862row4_col0 {
#             background-color:  #6f92f3;
#             color:  #000000;
#         }    #T_371f38e2_d573_11e9_a914_605718ad0862row4_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_371f38e2_d573_11e9_a914_605718ad0862row4_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_371f38e2_d573_11e9_a914_605718ad0862row4_col3 {
#             background-color:  #d4dbe6;
#             color:  #000000;
#         }    #T_371f38e2_d573_11e9_a914_605718ad0862row4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_371f38e2_d573_11e9_a914_605718ad0862row4_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_371f38e2_d573_11e9_a914_605718ad0862row4_col6 {
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }    #T_371f38e2_d573_11e9_a914_605718ad0862row4_col7 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_371f38e2_d573_11e9_a914_605718ad0862row4_col8 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_371f38e2_d573_11e9_a914_605718ad0862row4_col9 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_371f38e2_d573_11e9_a914_605718ad0862row5_col0 {
#             background-color:  #6687ed;
#             color:  #000000;
#         }    #T_371f38e2_d573_11e9_a914_605718ad0862row5_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_371f38e2_d573_11e9_a914_605718ad0862row5_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_371f38e2_d573_11e9_a914_605718ad0862row5_col3 {
#             background-color:  #c4d5f3;
#             color:  #000000;
#         }    #T_371f38e2_d573_11e9_a914_605718ad0862row5_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_371f38e2_d573_11e9_a914_605718ad0862row5_col5 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_371f38e2_d573_11e9_a914_605718ad0862row5_col6 {
#             background-color:  #516ddb;
#             color:  #000000;
#         }    #T_371f38e2_d573_11e9_a914_605718ad0862row5_col7 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }    #T_371f38e2_d573_11e9_a914_605718ad0862row5_col8 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_371f38e2_d573_11e9_a914_605718ad0862row5_col9 {
#             background-color:  #4358cb;
#             color:  #f1f1f1;

# %%
#Corelation matrix of Features: Fall Data
FEATURES =['Volume', 'NewProduct', 'Contract', 'Future_Contract', 'Popularity', 'Orders', 'Ordered_Units', 'Avg_Daily_Ordered_Units', 'Days_Ordered', 'Order_Volume', 'Avg_Daily_Volume']
corr_Fall = dfFall_resampled[FEATURES].corr()
corr_Fall.style.background_gradient(cmap='coolwarm', axis=None)
# Out:
# <style  type="text/css" >
#     #T_00d0ba1e_d574_11e9_8413_605718ad0862row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_00d0ba1e_d574_11e9_8413_605718ad0862row0_col1 {
#             background-color:  #a7c5fe;
#             color:  #000000;
#         }    #T_00d0ba1e_d574_11e9_8413_605718ad0862row0_col2 {
#             background-color:  #a6c4fe;
#             color:  #000000;
#         }    #T_00d0ba1e_d574_11e9_8413_605718ad0862row0_col3 {
#             background-color:  #c6d6f1;
#             color:  #000000;
#         }    #T_00d0ba1e_d574_11e9_8413_605718ad0862row0_col4 {
#             background-color:  #a7c5fe;
#             color:  #000000;
#         }    #T_00d0ba1e_d574_11e9_8413_605718ad0862row0_col5 {
#             background-color:  #aac7fd;
#             color:  #000000;
#         }    #T_00d0ba1e_d574_11e9_8413_605718ad0862row0_col6 {
#             background-color:  #a5c3fe;
#             color:  #000000;
#         }    #T_00d0ba1e_d574_11e9_8413_605718ad0862row0_col7 {
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }    #T_00d0ba1e_d574_11e9_8413_605718ad0862row0_col8 {
#             background-color:  #ecd3c5;
#             color:  #000000;
#         }    #T_00d0ba1e_d574_11e9_8413_605718ad0862row0_col9 {
#             background-color:  #df634e;
#             color:  #000000;
#         }    #T_00d0ba1e_d574_11e9_8413_605718ad0862row1_col0 {
#             background-color:  #a7c5fe;
#             color:  #000000;
#         }    #T_00d0ba1e_d574_11e9_8413_605718ad0862row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_00d0ba1e_d574_11e9_8413_605718ad0862row1_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_00d0ba1e_d574_11e9_8413_605718ad0862row1_col3 {
#             background-color:  #cad8ef;
#             color:  #000000;
#         }    #T_00d0ba1e_d574_11e9_8413_605718ad0862row1_col4 {
#             background-color:  #d44e41;
#             color:  #000000;
#         }    #T_00d0ba1e_d574_11e9_8413_605718ad0862row1_col5 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_00d0ba1e_d574_11e9_8413_605718ad0862row1_col6 {
#             background-color:  #f18f71;
#             color:  #000000;
#         }    #T_00d0ba1e_d574_11e9_8413_605718ad0862row1_col7 {
#             background-color:  #e9d5cb;
#             color:  #000000;
#         }    #T_00d0ba1e_d574_11e9_8413_605718ad0862row1_col8 {
#             background-color:  #f7af91;
#             color:  #000000;
#         }    #T_00d0ba1e_d574_11e9_8413_605718ad0862row1_col9 {
#             background-color:  #bbd1f8;
#             color:  #000000;
#         }    #T_00d0ba1e_d574_11e9_8413_605718ad0862row2_col0 {
#             background-color:  #a6c4fe;
#             color:  #000000;
#         }    #T_00d0ba1e_d574_11e9_8413_605718ad0862row2_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_00d0ba1e_d574_11e9_8413_605718ad0862row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_00d0ba1e_d574_11e9_8413_605718ad0862row2_col3 {
#             background-color:  #c7d7f0;
#             color:  #000000;
#         }    #T_00d0ba1e_d574_11e9_8413_605718ad0862row2_col4 {
#             background-color:  #d75445;
#             color:  #000000;
#         }    #T_00d0ba1e_d574_11e9_8413_605718ad0862row2_col5 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_00d0ba1e_d574_11e9_8413_605718ad0862row2_col6 {
#             background-color:  #f08b6e;
#             color:  #000000;
#         }    #T_00d0ba1e_d574_11e9_8413_605718ad0862row2_col7 {
#             background-color:  #e8d6cc;
#             color:  #000000;
#         }    #T_00d0ba1e_d574_11e9_8413_605718ad0862row2_col8 {
#             background-color:  #f7b396;
#             color:  #000000;
#         }    #T_00d0ba1e_d574_11e9_8413_605718ad0862row2_col9 {
#             background-color:  #bbd1f8;
#             color:  #000000;
#         }    #T_00d0ba1e_d574_11e9_8413_605718ad0862row3_col0 {
#             background-color:  #c6d6f1;
#             color:  #000000;
#         }    #T_00d0ba1e_d574_11e9_8413_605718ad0862row3_col1 {
#             background-color:  #cad8ef;
#             color:  #000000;
#         }    #T_00d0ba1e_d574_11e9_8413_605718ad0862row3_col2 {
#             background-color:  #c7d7f0;
#             color:  #000000;
#         }    #T_00d0ba1e_d574_11e9_8413_605718ad0862row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_00d0ba1e_d574_11e9_8413_605718ad0862row3_col4 {
#             background-color:  #c6d6f1;
#             color:  #000000;
#         }    #T_00d0ba1e_d574_11e9_8413_605718ad0862row3_col5 {
#             background-color:  #cad8ef;
#             color:  #000000;
#         }    #T_00d0ba1e_d574_11e9_8413_605718ad0862row3_col6 {
#             background-color:  #c9d7f0;
#             color:  #000000;
#         }    #T_00d0ba1e_d574_11e9_8413_605718ad0862row3_col7 {
#             background-color:  #d9dce1;
#             color:  #000000;
#         }    #T_00d0ba1e_d574_11e9_8413_605718ad0862row3_col8 {
#             background-color:  #c7d7f0;
#             color:  #000000;
#         }    #T_00d0ba1e_d574_11e9_8413_605718ad0862row3_col9 {
#             background-color:  #c4d5f3;
#             color:  #000000;
#         }    #T_00d0ba1e_d574_11e9_8413_605718ad0862row4_col0 {
#             background-color:  #a7c5fe;
#             color:  #000000;
#         }    #T_00d0ba1e_d574_11e9_8413_605718ad0862row4_col1 {
#             background-color:  #d44e41;
#             color:  #000000;
#         }    #T_00d0ba1e_d574_11e9_8413_605718ad0862row4_col2 {
#             background-color:  #d75445;
#             color:  #000000;
#         }    #T_00d0ba1e_d574_11e9_8413_605718ad0862row4_col3 {
#             background-color:  #c6d6f1;
#             color:  #000000;
#         }    #T_00d0ba1e_d574_11e9_8413_605718ad0862row4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_00d0ba1e_d574_11e9_8413_605718ad0862row4_col5 {
#             background-color:  #d95847;
#             color:  #000000;
#         }    #T_00d0ba1e_d574_11e9_8413_605718ad0862row4_col6 {
#             background-color:  #f4c5ad;
#             color:  #000000;
#         }    #T_00d0ba1e_d574_11e9_8413_605718ad0862row4_col7 {
#             background-color:  #f7af91;
#             color:  #000000;
#         }    #T_00d0ba1e_d574_11e9_8413_605718ad0862row4_col8 {
#             background-color:  #e26952;
#             color:  #000000;
#         }    #T_00d0ba1e_d574_11e9_8413_605718ad0862row4_col9 {
#             background-color:  #9bbcff;
#             color:  #000000;
#         }    #T_00d0ba1e_d574_11e9_8413_605718ad0862row5_col0 {
#             background-color:  #aac7fd;
#             color:  #000000;
#         }    #T_00d0ba1e_d574_11e9_8413_605718ad0862row5_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_00d0ba1e_d574_11e9_8413_605718ad0862row5_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_00d0ba1e_d574_11e9_8413_605718ad0862row5_col3 {
#             background-color:  #cad8ef;
#             color:  #000000;
#         }    #T_00d0ba1e_d574_11e9_8413_605718ad0862row5_col4 {
#             background-color:  #d95847;
#             color:  #000000;
#         }    #T_00d0ba1e_d574_11e9_8413_605718ad0862row5_col5 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_00d0ba1e_d574_11e9_8413_605718ad0862row5_col6 {
#             background-color:  #ef886b;
#             color:  #000000;
#         }    #T_00d0ba1e_d574_11e9_8413_605718ad0862row5_col7 {
#             background-color:  #e5d8d1;
#             color:  #000000;
#         }    #T_00d0ba1e_d574_11e9_8413_605718ad0862row5_col8 {
#             background-color:  #f7b194;
#             color:  #000000;
#         }    #T_00d0ba1e_d574_11e9_8413_605718ad0862row5_col9 {
#             background-color:  #bfd3f6;
#             color:  #000000;

# %%
# Find p-values (p) of Fall Corelation Matrix
r, p = corrcoef_loop(corr_Fall.values)
p_df = pd.DataFrame(p, columns=corr_Fall.columns, index=corr_Fall.index)
p_df.style.background_gradient(cmap='coolwarm', axis=None)
# Out:
# <style  type="text/css" >
#     #T_01005250_d574_11e9_a2ca_605718ad0862row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_01005250_d574_11e9_a2ca_605718ad0862row0_col1 {
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }    #T_01005250_d574_11e9_a2ca_605718ad0862row0_col2 {
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }    #T_01005250_d574_11e9_a2ca_605718ad0862row0_col3 {
#             background-color:  #f49a7b;
#             color:  #000000;
#         }    #T_01005250_d574_11e9_a2ca_605718ad0862row0_col4 {
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }    #T_01005250_d574_11e9_a2ca_605718ad0862row0_col5 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_01005250_d574_11e9_a2ca_605718ad0862row0_col6 {
#             background-color:  #b9d0f9;
#             color:  #000000;
#         }    #T_01005250_d574_11e9_a2ca_605718ad0862row0_col7 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_01005250_d574_11e9_a2ca_605718ad0862row0_col8 {
#             background-color:  #f4c5ad;
#             color:  #000000;
#         }    #T_01005250_d574_11e9_a2ca_605718ad0862row0_col9 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_01005250_d574_11e9_a2ca_605718ad0862row1_col0 {
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }    #T_01005250_d574_11e9_a2ca_605718ad0862row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_01005250_d574_11e9_a2ca_605718ad0862row1_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_01005250_d574_11e9_a2ca_605718ad0862row1_col3 {
#             background-color:  #9fbfff;
#             color:  #000000;
#         }    #T_01005250_d574_11e9_a2ca_605718ad0862row1_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_01005250_d574_11e9_a2ca_605718ad0862row1_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_01005250_d574_11e9_a2ca_605718ad0862row1_col6 {
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }    #T_01005250_d574_11e9_a2ca_605718ad0862row1_col7 {
#             background-color:  #89acfd;
#             color:  #000000;
#         }    #T_01005250_d574_11e9_a2ca_605718ad0862row1_col8 {
#             background-color:  #6282ea;
#             color:  #000000;
#         }    #T_01005250_d574_11e9_a2ca_605718ad0862row1_col9 {
#             background-color:  #6a8bef;
#             color:  #000000;
#         }    #T_01005250_d574_11e9_a2ca_605718ad0862row2_col0 {
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }    #T_01005250_d574_11e9_a2ca_605718ad0862row2_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_01005250_d574_11e9_a2ca_605718ad0862row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_01005250_d574_11e9_a2ca_605718ad0862row2_col3 {
#             background-color:  #9ebeff;
#             color:  #000000;
#         }    #T_01005250_d574_11e9_a2ca_605718ad0862row2_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_01005250_d574_11e9_a2ca_605718ad0862row2_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_01005250_d574_11e9_a2ca_605718ad0862row2_col6 {
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }    #T_01005250_d574_11e9_a2ca_605718ad0862row2_col7 {
#             background-color:  #8db0fe;
#             color:  #000000;
#         }    #T_01005250_d574_11e9_a2ca_605718ad0862row2_col8 {
#             background-color:  #6485ec;
#             color:  #000000;
#         }    #T_01005250_d574_11e9_a2ca_605718ad0862row2_col9 {
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }    #T_01005250_d574_11e9_a2ca_605718ad0862row3_col0 {
#             background-color:  #f49a7b;
#             color:  #000000;
#         }    #T_01005250_d574_11e9_a2ca_605718ad0862row3_col1 {
#             background-color:  #9fbfff;
#             color:  #000000;
#         }    #T_01005250_d574_11e9_a2ca_605718ad0862row3_col2 {
#             background-color:  #9ebeff;
#             color:  #000000;
#         }    #T_01005250_d574_11e9_a2ca_605718ad0862row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_01005250_d574_11e9_a2ca_605718ad0862row3_col4 {
#             background-color:  #a9c6fd;
#             color:  #000000;
#         }    #T_01005250_d574_11e9_a2ca_605718ad0862row3_col5 {
#             background-color:  #9dbdff;
#             color:  #000000;
#         }    #T_01005250_d574_11e9_a2ca_605718ad0862row3_col6 {
#             background-color:  #c3d5f4;
#             color:  #000000;
#         }    #T_01005250_d574_11e9_a2ca_605718ad0862row3_col7 {
#             background-color:  #ee8669;
#             color:  #000000;
#         }    #T_01005250_d574_11e9_a2ca_605718ad0862row3_col8 {
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }    #T_01005250_d574_11e9_a2ca_605718ad0862row3_col9 {
#             background-color:  #f7ba9f;
#             color:  #000000;
#         }    #T_01005250_d574_11e9_a2ca_605718ad0862row4_col0 {
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }    #T_01005250_d574_11e9_a2ca_605718ad0862row4_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_01005250_d574_11e9_a2ca_605718ad0862row4_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_01005250_d574_11e9_a2ca_605718ad0862row4_col3 {
#             background-color:  #a9c6fd;
#             color:  #000000;
#         }    #T_01005250_d574_11e9_a2ca_605718ad0862row4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_01005250_d574_11e9_a2ca_605718ad0862row4_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_01005250_d574_11e9_a2ca_605718ad0862row4_col6 {
#             background-color:  #799cf8;
#             color:  #000000;
#         }    #T_01005250_d574_11e9_a2ca_605718ad0862row4_col7 {
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }    #T_01005250_d574_11e9_a2ca_605718ad0862row4_col8 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_01005250_d574_11e9_a2ca_605718ad0862row4_col9 {
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }    #T_01005250_d574_11e9_a2ca_605718ad0862row5_col0 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_01005250_d574_11e9_a2ca_605718ad0862row5_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_01005250_d574_11e9_a2ca_605718ad0862row5_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_01005250_d574_11e9_a2ca_605718ad0862row5_col3 {
#             background-color:  #9dbdff;
#             color:  #000000;
#         }    #T_01005250_d574_11e9_a2ca_605718ad0862row5_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_01005250_d574_11e9_a2ca_605718ad0862row5_col5 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_01005250_d574_11e9_a2ca_605718ad0862row5_col6 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_01005250_d574_11e9_a2ca_605718ad0862row5_col7 {
#             background-color:  #98b9ff;
#             color:  #000000;
#         }    #T_01005250_d574_11e9_a2ca_605718ad0862row5_col8 {
#             background-color:  #6788ee;
#             color:  #000000;
#         }    #T_01005250_d574_11e9_a2ca_605718ad0862row5_col9 {
#             background-color:  #7396f5;
#             color:  #000000;

# %%
# # Create one-vs-rest multinomial logistic regression object
# clf = LogisticRegression(random_state=0, multi_class='multi', solver='newton-cg')

# FEATURE_SET = ['NewProduct', 'Volume', 'Orders', 'Ordered_Units', 'Days_Ordered', 'Avg_Daily_Volume']
FEATURE_SET = ['NewProduct', 'Ordered_Units','Order_Volume']

TARGET_CLUSTER = ['KMeans_Cluster3_Label']
TARGET_CLASS = ['Class']

# SPRING DATA
spring_X = dfSpring_resampled[FEATURE_SET] # Spring Training Set
spring_y1 = dfSpring_resampled[TARGET_CLUSTER] # Target: 3-cluster labels
spring_y2 = dfSpring_resampled[TARGET_CLASS]    # Target: Class (Dale's classification)
# spring_cluster_y1 = dfSpring_resampled['Cluster_1'] # Target: Spring Cluster_1 binary response
# spring_cluster_y2 = dfSpring_resampled['Cluster_2'] # Target: Spring Cluster_2 binary response
# spring_cluster_y3 = dfSpring_resampled['Cluster_3'] # Target: Spring Cluster_3 binary response

# FALL DATA
fall_X = dfFall_resampled[FEATURE_SET] # Fall Training Set
fall_y1 = dfFall_resampled[TARGET_CLUSTER] # Target: 3-cluster labels
fall_y2 = dfFall_resampled[TARGET_CLASS]    # Target: Class (Dale's classification)
# fall_cluster_y1 = dfFall_resampled['Cluster_1'] # Target: Fall Cluster_1 binary response
# fall_cluster_y2 = dfFall_resampled['Cluster_2'] # Target: Fall Cluster_2 binary response
# fall_cluster_y3 = dfFall_resampled['Cluster_3'] # Target: Fall Cluster_3 binary response

# %% [markdown]
# #### Multinomial Logit - Fit Statistics

# %%
# # Train Model and get the Fit Statistics
# # Target: Spring Cluster_1 binary response
# logit_model=sm.Logit(spring_cluster_y1.astype(float),spring_X.astype(float))
# result=logit_model.fit()
# print(result.summary())

# %%
# # Train Model and get the Fit Statistics
# # Target: Spring Cluster_2 binary response
# logit_model=sm.Logit(spring_cluster_y2.astype(float),spring_X.astype(float))
# result=logit_model.fit()
# print(result.summary())

# %%
# # Train Model and get the Fit Statistics
# # Target: Spring Cluster_3 binary response
# logit_model=sm.Logit(spring_cluster_y3.astype(float),spring_X.astype(float))
# result=logit_model.fit()
# print(result.summary())

# %%
# # Train Model and get the Fit Statistics
# # Target: Fall Cluster_1 binary response
# logit_model=sm.Logit(fall_cluster_y1.astype(float),fall_X.astype(float))
# result=logit_model.fit()
# print(result.summary())

# %%
# # Train Model and get the Fit Statistics
# # Target: Fall Cluster_2 binary response
# logit_model=sm.Logit(fall_cluster_y2.astype(float),fall_X.astype(float))
# result=logit_model.fit()
# print(result.summary())

# %%
# # Train Model and get the Fit Statistics
# # Target: Fall Cluster_3 binary response
# logit_model=sm.Logit(fall_cluster_y3.astype(float),fall_X.astype(float))
# result=logit_model.fit()
# print(result.summary())

# %%
# Train Model and get the Fit Statistics
# Target: Target: 3-cluster labels
logit_model=sm.MNLogit(spring_y1.astype(float),spring_X.astype(float))
result=logit_model.fit()
print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.869291
#          Iterations 9
#                             MNLogit Regression Results
# =================================================================================
# Dep. Variable:     KMeans_Cluster3_Label   No. Observations:                 2280
# Model:                           MNLogit   Df Residuals:                     2274
# Method:                              MLE   Df Model:                            4
# Date:                   Thu, 12 Sep 2019   Pseudo R-squ.:                  0.2087
# Time:                           12:09:14   Log-Likelihood:                -1982.0
# converged:                          True   LL-Null:                       -2504.8
#                                            LLR p-value:                4.436e-225
# ===========================================================================================
# KMeans_Cluster3_Label=2       coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# NewProduct                 -1.8542      0.195     -9.503      0.000      -2.237      -1.472
# Ordered_Units               0.0002   3.39e-05      5.192      0.000       0.000       0.000
# Order_Volume             5.398e-07   8.91e-08      6.057      0.000    3.65e-07    7.14e-07
# -------------------------------------------------------------------------------------------
# KMeans_Cluster3_Label=3       coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# NewProduct                 -1.3720      0.186     -7.387      0.000      -1.736      -1.008
# Ordered_Units               0.0002   3.46e-05      5.494      0.000       0.000       0.000
# Order_Volume            -1.539e-07   1.06e-07     -1.450      0.147   -3.62e-07    5.41e-08
# ===========================================================================================

# %%
# Train Model and get the Fit Statistics
# Target: Target: 3-cluster labels
logit_model=sm.MNLogit(fall_y1.astype(float),fall_X.astype(float))
result=logit_model.fit()
print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: nan
#          Iterations 7
#                             MNLogit Regression Results
# =================================================================================
# Dep. Variable:     KMeans_Cluster3_Label   No. Observations:                 2547
# Model:                           MNLogit   Df Residuals:                     2541
# Method:                              MLE   Df Model:                            4
# Date:                   Thu, 12 Sep 2019   Pseudo R-squ.:                     nan
# Time:                           12:09:14   Log-Likelihood:                    nan
# converged:                          True   LL-Null:                       -2798.2
#                                            LLR p-value:                       nan
# ===========================================================================================
# KMeans_Cluster3_Label=2       coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# NewProduct                     nan        nan        nan        nan         nan         nan
# Ordered_Units                  nan        nan        nan        nan         nan         nan
# Order_Volume                   nan        nan        nan        nan         nan         nan
# -------------------------------------------------------------------------------------------
# KMeans_Cluster3_Label=3       coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# NewProduct                     nan        nan        nan        nan         nan         nan
# Ordered_Units                  nan        nan        nan        nan         nan         nan
# Order_Volume                   nan        nan        nan        nan         nan         nan
# ===========================================================================================

# %%
# Train Model and get the Fit Statistics
# Target: Class (Dale's classification)
logit_model=sm.MNLogit(spring_y2.astype(float),spring_X.astype(float))
result=logit_model.fit()
print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.937216
#          Iterations 8
#                           MNLogit Regression Results
# ==============================================================================
# Dep. Variable:                  Class   No. Observations:                 2280
# Model:                        MNLogit   Df Residuals:                     2274
# Method:                           MLE   Df Model:                            4
# Date:                Thu, 12 Sep 2019   Pseudo R-squ.:                 0.08061
# Time:                        12:09:14   Log-Likelihood:                -2136.9
# converged:                       True   LL-Null:                       -2324.2
#                                         LLR p-value:                 8.050e-80
# =================================================================================
#       Class=2       coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# NewProduct       -0.8119      0.287     -2.829      0.005      -1.374      -0.249
# Ordered_Units -7.314e-05    1.6e-05     -4.557      0.000      -0.000   -4.17e-05
# Order_Volume   1.457e-06   1.63e-07      8.940      0.000    1.14e-06    1.78e-06
# ---------------------------------------------------------------------------------
#       Class=3       coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# NewProduct        1.0927      0.208      5.248      0.000       0.685       1.501
# Ordered_Units -8.224e-05    1.6e-05     -5.153      0.000      -0.000    -5.1e-05
# Order_Volume    1.65e-06   1.63e-07     10.149      0.000    1.33e-06    1.97e-06
# =================================================================================

# %%
# Train Model and get the Fit Statistics
# Target: Class (Dale's classification)
logit_model=sm.MNLogit(fall_y2.astype(float),fall_X.astype(float))
result=logit_model.fit()
print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.479002
#          Iterations 9
#                           MNLogit Regression Results
# ==============================================================================
# Dep. Variable:                  Class   No. Observations:                 2547
# Model:                        MNLogit   Df Residuals:                     2541
# Method:                           MLE   Df Model:                            4
# Date:                Thu, 12 Sep 2019   Pseudo R-squ.:                  0.4119
# Time:                        12:09:14   Log-Likelihood:                -1220.0
# converged:                       True   LL-Null:                       -2074.7
#                                         LLR p-value:                     0.000
# =================================================================================
#       Class=2       coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# NewProduct       -1.6218      0.249     -6.525      0.000      -2.109      -1.135
# Ordered_Units -3.459e-05   5.56e-06     -6.222      0.000   -4.55e-05   -2.37e-05
# Order_Volume   8.423e-07   9.01e-08      9.346      0.000    6.66e-07    1.02e-06
# ---------------------------------------------------------------------------------
#       Class=3       coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# NewProduct        1.1599      0.185      6.285      0.000       0.798       1.522
# Ordered_Units -3.836e-05   5.16e-06     -7.433      0.000   -4.85e-05   -2.82e-05
# Order_Volume   1.056e-06   8.83e-08     11.963      0.000    8.83e-07    1.23e-06
# =================================================================================

# %%
# # Train Model and get the Accuracy Score
# # Target: 3-cluster labels of Spring
# spring_model1 = clf.fit(spring_X, spring_y1)
# spring_accuracy1 = spring_model1.score(spring_X, spring_y1)
# print("\nAccuracy of Spring data with 3-cluster labels: ", spring_accuracy1)

# # Train Model and get the Accuracy Score
# # Target: Class (Dale's classification)
# spring_model2 = clf.fit(spring_X, spring_y2)
# spring_accuracy2 = spring_model2.score(spring_X, spring_y2)
# print("\nAccuracy of Spring data with class labels: ", spring_accuracy2)

# %%
# # Train Model and get the Accuracy Score
# # Target: 3-cluster labels of Fall
# fall_model1 = clf.fit(fall_X, fall_y1)
# fall_accuracy1 = fall_model1.score(fall_X, fall_y1)
# print("\nAccuracy of Fall data with 3-cluster labels: ", fall_accuracy1)

# # Train Model and get the Accuracy Score
# # Target: Class (Dale's classification)
# fall_model2 = clf.fit(fall_X, fall_y2)
# fall_accuracy2 = fall_model2.score(fall_X, fall_y2)
# print("\nAccuracy of Fall data with class labels: ", fall_accuracy2)
